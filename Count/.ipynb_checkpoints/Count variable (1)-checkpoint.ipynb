# %%
import statsmodels.api as sm
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.feature_selection import RFE
from sklearn.linear_model import RidgeCV, LassoCV, Ridge, Lasso
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score
from sklearn.feature_selection import SelectFromModel

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import itertools

from sklearn.linear_model import LinearRegression, RidgeCV, LassoCV, ElasticNetCV, LarsCV
from sklearn import svm
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import train_test_split

import warnings
warnings.filterwarnings("ignore")

# %%
Data = pd.read_csv('count.csv')
Data = Data.drop('id', axis = 1)
Data
# Out:
#      yC         x1     x2  x3  x4  x5  x6  x7        x8  x9    ...        x23  \
# 0     1  49.856000  118.8   1   0   0   0   0  16.32096   0    ...     0.9709
# 1     0  71.836000   34.8   0   0   0   0   1  15.00535  44    ...     0.4200
# 2     0  66.725000   41.8   0   1   0   0   0  17.07023  27    ...     0.9650
# 3     0  41.696000  132.0   0   0   1   0   0  16.31460   0    ...     0.0091
# 4     2  71.351000   24.2   1   0   0   0   0  11.10790  31    ...     0.0051
# 5     3  71.565000   25.4   0   0   0   1   0  17.30379  38    ...     0.0000
# 6     1  67.879000   42.3   0   0   0   0   1  15.07912  31    ...     0.0022
# 7     1  76.994634    7.6   1   0   0   0   0  16.65255  45    ...     0.0094
# 8     0  75.568293    8.0   0   0   0   0   0  15.85385  45    ...     0.0204
# 9     0  64.827000   75.9   0   0   0   0   0  15.78388  31    ...     0.9000
# 10    2  70.705000   19.6   1   0   0   0   0  12.45424  31    ...     0.0000
# 11    2  72.390000   19.6   1   0   0   0   0  13.11419  31    ...     0.8635
# 12    2  58.401000   99.7   1   0   0   0   0  18.48073   0    ...     0.8830
# 13    1  71.383000   16.0   1   0   0   0   0  12.46987  31    ...     0.0042
# 14    2  70.836585   12.2   0   0   0   0   0  16.13682  31    ...     0.0015
# 15    3  76.051951    8.3   0   0   0   0   0  16.11483  45    ...     0.0316
# 16    1  71.246000   31.3   1   0   0   0   0  12.14181  31    ...     0.0053
# 17    0  53.812000  107.1   0   1   0   0   0  15.42064  31    ...     0.1836
# 18    2  52.879000   89.6   1   0   0   0   0  13.19427  45    ...     0.0103
# 19    0  55.104000   85.3   0   0   0   1   0  15.74067  42    ...     0.0002
# 20    1  70.877000   16.1   0   0   0   0   1  15.31143  31    ...     0.4037
# 21    2  61.905000   39.5   1   0   0   0   0  14.13608  31    ...     0.0018
# 22    0  65.300000   52.6   0   0   1   0   0  18.82182  45    ...     0.0003
# 23    0  71.641463   14.6   0   0   0   0   1  15.98093  45    ...     0.1235
# 24    1  49.454000   99.1   0   1   0   0   0  15.99152  29    ...     0.4862
# 25    1  48.053000  105.4   0   0   0   0   0  15.50476  30    ...     0.0194
# 26    1  64.877000   48.2   0   0   1   0   0  12.74222  31    ...     0.0223
# 27    0  53.595000   84.7   0   1   0   0   0  16.00977   0    ...     0.0233
# 28    2  52.209000   86.0   0   1   0   0   0  16.27640  28    ...     0.2120
# 29    1  77.377073    6.8   1   0   0   0   0  17.14022  45    ...     0.0090
# ..   ..        ...    ...  ..  ..  ..  ..  ..       ...  ..    ...        ...
# 120   2  60.050000  106.4   1   0   0   0   0  18.49466   0    ...     0.9487
# 121   0  72.987000   25.6   0   0   0   1   0  14.72014  44    ...     0.0146
# 122   3  58.865000   64.1   1   0   0   0   0  15.27716   0    ...     0.0002
# 123   0  68.014000   36.3   0   0   0   1   0  15.25386  42    ...     0.0000
# 124   3  65.541000   57.0   0   0   0   1   0  16.89864   0    ...     0.0000
# 125   6  65.256000   40.5   0   0   0   1   0  17.94180   0    ...     0.0460
# 126   2  70.890244   15.1   0   0   0   0   0  17.45601  45    ...     0.0001
# 127   1  73.965854   11.5   0   0   0   0   0  16.11642  45    ...     0.0020
# 128   2  74.984000   17.8   1   0   0   0   0  13.07411  31    ...     0.8572
# 129   0  69.741220   24.4   0   0   0   0   1  16.95974  44    ...     0.0020
# 130   0  68.886098   18.5   0   0   0   0   0  18.81469   0    ...     0.1014
# 131   1  34.217000   92.6   0   0   0   0   0  15.79455   0    ...     0.0774
# 132   1  64.851000   25.4   0   0   0   0   0  12.00068  31    ...     0.0002
# 133   0  69.017000   35.6   0   0   0   0   1  16.60832  44    ...     0.9485
# 134   0  57.202000   71.2   0   1   0   0   0  15.83780   0    ...     0.8779
# 135   5  68.107317   14.4   1   0   0   0   0  11.14918  31    ...     0.0023
# 136   4  37.348000  155.4   1   0   0   0   0  15.27697  31    ...     0.4500
# 137   0  75.295122    6.2   1   0   0   0   0  14.92971  32    ...     0.1830
# 138   1  70.932683   12.6   0   0   0   0   0  15.48306  31    ...     0.0000
# 139   0  73.204878    8.8   0   0   0   0   0  14.50774  31    ...     0.0240
# 140   2  56.638000   31.2   1   0   0   0   0  12.65025  31    ...     0.0014
# 141   0  45.375000  108.2   0   0   0   0   0  15.81663   0    ...     0.9942
# 142   7  62.062000   46.9   1   0   0   0   0  17.44146  22    ...     0.0118
# 143   0  76.837561    7.5   0   0   0   0   0  17.47566  37    ...     0.0044
# 144   0  69.511000   18.1   1   0   0   0   0  16.66793   0    ...     0.0883
# 145   4  65.951220   26.1   1   0   0   0   0  10.61727  31    ...     0.0000
# 146   4  71.108000   18.6   1   0   0   0   0  11.83635  31    ...     0.0000
# 147   2  70.140000   20.2   1   0   0   0   0  11.58529  31    ...     0.0142
# 148   2  55.500000   82.1   1   0   0   0   0  16.81860   0    ...     0.6751
# 149   2  67.393000   40.9   0   0   0   0   0  12.91773  30    ...     0.1619
#
#         x24  x25  x26       x27  x28  x29  x30       x31       x32
# 0    0.0003    6    6   24.7138    0    0    7  0.056546  0.112860
# 1    0.0000    8    4   38.0658    0    0    7  0.655260  0.886908
# 2    0.0000    6    6   48.3807    0    1    4  0.067855  0.133944
# 3    0.0001    6    4   59.8410    0    0    7  0.133230  0.260102
# 4    0.0000    5    7  175.9250    0    0    3  0.318584  0.627729
# 5    0.0000    5    7   14.9909    1    0    1  0.173189  0.330825
# 6    0.0001    7    3   81.3357    0    0    5  0.219665  0.436101
# 7    0.0082    6    6   31.9150    1    0    1  0.297416  0.558743
# 8    0.0000    8    4   73.9691    1    0    1  0.285290  0.539237
# 9    0.0000    7    3   83.0969    0    0    5  0.185113  0.342531
# 10   0.0000    6    6  110.1200    0    0    2  0.292938  0.583095
# 11   0.0002    6    6  210.1610    0    0    6  0.244678  0.442987
# 12   0.0060    7    5   19.6527    0    0    5  0.208174  0.408118
# 13   0.0004    6    6  100.8310    0    0    1  0.431135  0.850350
# 14   0.0001    5    6   89.6074    0    0    4  0.425556  0.839806
# 15   0.0020    6    6  132.3320    1    0    1  0.260125  0.476567
# 16   0.0032    6    6  122.2850    0    0    1  0.234838  0.445292
# 17   0.0000    7    6   40.6187    0    0    6  0.597977  0.867463
# 18   0.7376    4    7   61.2636    0    0    6  0.396755  0.750471
# 19   0.0007    6    6   46.7033    0    0    2  0.087340  0.174012
# 20   0.0000    8    4  101.8470    1    0    6  0.569496  0.925681
# 21   0.0000    5    7  104.8470    0    0    1  0.498279  0.990623
# 22   0.0016    7    4   15.1618    1    0    2  0.088353  0.175436
# 23   0.0000    7    4   69.8471    0    0    3  0.386285  0.646249
# 24   0.0000    7    6   35.4226    0    0    6  0.608286  0.899569
# 25   0.0000    7    6   35.6481    0    0    7  0.189326  0.361043
# 26   0.0000    5    6   85.9516    0    0    5  0.077778  0.150983
# 27   0.8466    6    5   13.5338    0    0    7  0.268420  0.492368
# 28   0.0000    7    6   37.4964    0    0    6  0.609842  0.868955
# 29   0.0180    6    6   51.4967    1    0    1  0.220329  0.400807
# ..      ...  ...  ...       ...  ...  ...  ...       ...       ...
# 120  0.0007    7    5   38.9095    1    0    4  0.098533  0.190252
# 121  0.0051    6    6  165.3840    0    0    4  0.085258  0.164009
# 122  0.0015    6    6   89.5715    0    0    2  0.094994  0.188995
# 123  0.0015    6    6   72.7405    0    0    4  0.035614  0.070821
# 124  0.0003    5    6   29.5980    0    0    3  0.020398  0.040737
# 125  0.0010    4    6   60.8003    0    0    3  0.137878  0.261636
# 126  0.0000    6    6   45.8570    0    0    2  0.054443  0.108821
# 127  0.0051    6    6   66.3074    0    0    1  0.106453  0.208795
# 128  0.0185    6    6   78.6499    0    1    7  0.256984  0.450547
# 129  0.0000    8    4   42.9071    0    0    6  0.159767  0.317292
# 130  0.0020    7    3   36.1068    1    0    5  0.517031  0.807412
# 131  0.0000    8    6   19.6842    0    0    6  0.346902  0.599028
# 132  0.0001    7    6   72.7679    0    0    2  0.053315  0.106534
# 133  0.0036    6    6   72.2313    0    1    7  0.098990  0.190594
# 134  0.0001    7    6   57.5961    0    0    4  0.221773  0.404617
# 135  0.0000    5    6  129.2260    0    0    6  0.057007  0.113291
# 136  0.0000    7    7   46.2159    0    0    6  0.593827  0.920821
# 137  0.1500    6    6  344.8300    0    0    4  0.627782  0.778637
# 138  0.0000    8    4   62.0863    0    0    3  0.397142  0.793808
# 139  0.0000    8    4  169.2890    0    0    2  0.190566  0.360265
# 140  0.0033    5    6   94.7451    0    0    1  0.095435  0.188388
# 141  0.0000    6    6   47.5282    0    0    7  0.011540  0.023037
# 142  0.0018    5    7   42.9994    1    0    5  0.351613  0.670549
# 143  0.0004    7    5   35.5214    1    0    1  0.074197  0.146396
# 144  0.6856    8    5   68.2439    0    0    4  0.494039  0.717006
# 145  0.0000    6    7  134.8940    1    0    1  0.215742  0.431484
# 146  0.0000    5    7  156.7250    0    0    1  0.028774  0.057547
# 147  0.0000    7    7  142.6430    0    0    1  0.240689  0.463257
# 148  0.0000    6    6   11.0874    0    0    7  0.491452  0.769145
# 149  0.0035    7    6   86.4924    0    0    4  0.569559  0.841062
#
# [150 rows x 33 columns]

# %%
desc = Data.describe().transpose()
desc['type'] = Data.dtypes
desc
# Out:
#      count        mean         std        min        25%        50%  \
# yC   150.0    1.306667    1.335859   0.000000   0.000000   1.000000
# x1   150.0   64.315059   10.050340  34.217000  56.866750  67.754500
# x2   150.0   50.366667   41.298169   4.600000  14.725000  40.000000
# x3   150.0    0.300000    0.459793   0.000000   0.000000   0.000000
# x4   150.0    0.146667    0.354958   0.000000   0.000000   0.000000
# x5   150.0    0.040000    0.196616   0.000000   0.000000   0.000000
# x6   150.0    0.120000    0.326050   0.000000   0.000000   0.000000
# x7   150.0    0.100000    0.301005   0.000000   0.000000   0.000000
# x8   150.0   15.403789    1.929863  10.617270  14.507013  15.463720
# x9   150.0   27.593333   15.434684   0.000000  25.500000  31.000000
# x10  150.0  139.556769  397.363194   1.405897  17.241500  53.866725
# x11  150.0    7.803776    1.505953   4.948077   6.580687   7.748950
# x12  150.0    7.774620   11.453525   0.000000   0.260553   2.714070
# x13  150.0    0.233333    0.424370   0.000000   0.000000   0.000000
# x14  150.0    0.200000    0.401340   0.000000   0.000000   0.000000
# x15  150.0    0.206667    0.406271   0.000000   0.000000   0.000000
# x16  150.0    0.200000    0.401340   0.000000   0.000000   0.000000
# x17  150.0    0.313333    0.465403   0.000000   0.000000   0.000000
# x18  150.0    0.100000    0.301005   0.000000   0.000000   0.000000
# x19  150.0    0.106667    0.309723   0.000000   0.000000   0.000000
# x20  150.0    0.040000    0.196616   0.000000   0.000000   0.000000
# x21  150.0    0.558024    0.378927   0.000400   0.109500   0.713800
# x22  150.0    0.006207    0.064490   0.000000   0.000000   0.000050
# x23  150.0    0.239536    0.350769   0.000000   0.001625   0.021850
# x24  150.0    0.032573    0.134419   0.000000   0.000000   0.000100
# x25  150.0    6.380000    0.924462   4.000000   6.000000   6.000000
# x26  150.0    5.586667    0.963680   3.000000   5.000000   6.000000
# x27  150.0   78.493669   47.992359  11.087400  44.936225  66.404000
# x28  150.0    0.133333    0.341073   0.000000   0.000000   0.000000
# x29  150.0    0.053333    0.225450   0.000000   0.000000   0.000000
# x30  150.0    3.926667    2.186280   1.000000   2.000000   4.000000
# x31  150.0    0.283136    0.193801   0.011540   0.100434   0.247636
# x32  150.0    0.491055    0.299361   0.023037   0.194432   0.461095
#
#             75%          max     type
# yC     2.000000     7.000000    int64
# x1    71.519725    78.836829  float64
# x2    81.400000   173.700000  float64
# x3     1.000000     1.000000    int64
# x4     0.000000     1.000000    int64
# x5     0.000000     1.000000    int64
# x6     0.000000     1.000000    int64
# x7     0.000000     1.000000    int64
# x8    16.586320    20.850060  float64
# x9    39.750000    45.000000    int64
# x10  123.527010  4547.958200  float64
# x11    8.986054    10.806890  float64
# x12   10.344950    47.476500  float64
# x13    0.000000     1.000000    int64
# x14    0.000000     1.000000    int64
# x15    0.000000     1.000000    int64
# x16    0.000000     1.000000    int64
# x17    1.000000     1.000000    int64
# x18    0.000000     1.000000    int64
# x19    0.000000     1.000000    int64
# x20    0.000000     1.000000    int64
# x21    0.914425     0.989700  float64
# x22    0.000500     0.790100  float64
# x23    0.415925     0.994200  float64
# x24    0.001500     0.846600  float64
# x25    7.000000     9.000000    int64
# x26    6.000000     7.000000    int64
# x27  102.720000   344.830000  float64
# x28    0.000000     1.000000    int64
# x29    0.000000     1.000000    int64
# x30    6.000000     7.000000    int64
# x31    0.436986     0.662330  float64
# x32    0.797946     0.996328  float64

# %%
Y = Data['yC']
X = Data.drop('yC', axis = 1)

# %%
X_train, X_test, y_train, y_test = train_test_split(X,Y, test_size = 0.3, random_state = 0)

# %%
plt.hist(Y, bins = 8)
plt.show()

# %% [markdown]
# ### Correlaciones

# %% [markdown]
# #### Pearson

# %%
plt.figure(figsize=(25,25))
pcor = Data.corr()
sns.heatmap(pcor, annot=True, cmap=plt.cm.Reds)
plt.show()

# %%
#Correlation with output variable
pcor_target = abs(pcor["yC"])
#Selecting highly correlated features
prelevant_features = pcor_target[pcor_target>0.5]
prelevant_features
# Out:
# yC    1.0
# Name: yC, dtype: float64

# %% [markdown]
# #### Spearman

# %%
plt.figure(figsize=(25,25))
scor = Data.corr(method='spearman')
sns.heatmap(scor, annot=True, cmap=plt.cm.Reds)
plt.show()

# %%
#Correlation with output variable
scor_target = abs(scor["yC"])
#Selecting highly correlated features
srelevant_features = scor_target[scor_target>0.5]
srelevant_features
# Out:
# yC    1.0
# Name: yC, dtype: float64

# %% [markdown]
# #### Kendal

# %%
plt.figure(figsize=(25,25))
kcor = Data.corr(method='kendall')
sns.heatmap(kcor, annot=True, cmap=plt.cm.Reds)
plt.show()

# %%
#Correlation with output variable
kcor_target = abs(kcor["yC"])
#Selecting highly correlated features
krelevant_features = kcor_target[kcor_target>0.5]
krelevant_features
# Out:
# yC    1.0
# Name: yC, dtype: float64

# %% [markdown]
# ## Select from Model

# %%
print(X_train.shape)
X_train.head()
# Out:
# (105, 32)
#          x1     x2  x3  x4  x5  x6  x7        x8  x9         x10    ...     \
# 60   70.268   40.8   0   0   0   0   0  15.38454  31   84.012737    ...
# 116  43.540  132.0   0   1   0   0   0  15.89656  31    6.325776    ...
# 144  69.511   18.1   1   0   0   0   0  16.66793   0  276.346880    ...
# 119  67.181   31.8   0   0   1   0   0  14.41003  37    5.855121    ...
# 108  60.268   76.9   0   0   0   0   0  14.59674  45    1.405897    ...
#
#         x23     x24  x25  x26      x27  x28  x29  x30       x31       x32
# 60   0.1100  0.0000    7    4  85.6379    0    0    6  0.270861  0.490698
# 116  0.9016  0.0000    7    6  36.9707    0    0    6  0.178963  0.349659
# 144  0.0883  0.6856    8    5  68.2439    0    0    4  0.494039  0.717006
# 119  0.8553  0.0065    6    6  74.8292    0    0    6  0.257866  0.462323
# 108  0.0429  0.4160    7    3  58.6219    0    0    4  0.543041  0.940667
#
# [5 rows x 32 columns]

# %%
lcv = LassoCV().fit(X_train, y_train)
model = SelectFromModel(lcv, prefit=True)
X_new = model.transform(X)

# %%
print(X_new.shape)
X_new[0,:]
# Out:
# (150, 13)
# array([  49.856   ,  118.8     ,    1.      ,   16.32096 ,    0.      ,
#          18.762237,    6.162105,    9.39728 ,    1.      ,    6.      ,
#           6.      ,   24.7138  ,    0.      ])

# %%
X.iloc[0,]
# Out:
# x1      49.856000
# x2     118.800000
# x3       1.000000
# x4       0.000000
# x5       0.000000
# x6       0.000000
# x7       0.000000
# x8      16.320960
# x9       0.000000
# x10     18.762237
# x11      6.162105
# x12      9.397280
# x13      0.000000
# x14      1.000000
# x15      0.000000
# x16      1.000000
# x17      0.000000
# x18      0.000000
# x19      0.000000
# x20      0.000000
# x21      0.000400
# x22      0.000000
# x23      0.970900
# x24      0.000300
# x25      6.000000
# x26      6.000000
# x27     24.713800
# x28      0.000000
# x29      0.000000
# x30      7.000000
# x31      0.056546
# x32      0.112860
# Name: 0, dtype: float64

# %%
import time
import os

import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import datetime as dt

# %%
#path = '/Users/diana/Library/Mobile Documents/com~apple~CloudDocs/Maestria/Aprendizaje Automático/HR_attrition_orig_proc.csv'
path = 'datacontinuousstudents.csv'
data = pd.read_csv(path, sep = ',', na_filter = False)
data = data.set_index('id')

# %%
# Columnas del dataframe
data.head()
# Out:
#            y      x1     x2  x3  x4  x5  x6  x7        x8  x9  ...     x23  \
# id                                                             ...
# 1  -0.852667  49.856  118.8   1   0   0   0   0  16.32096   0  ...  0.9709
# 2   0.685760  71.836   34.8   0   0   0   0   1  15.00535  44  ...  0.4200
# 3   5.951199  66.725   41.8   0   1   0   0   0  17.07023  27  ...  0.9650
# 4  -2.030599  41.696  132.0   0   0   1   0   0  16.31460   0  ...  0.0091
# 5  -6.143410  71.351   24.2   1   0   0   0   0  11.10790  31  ...  0.0051
#
#        x24  x25  x26       x27  x28  x29  x30       x31       x32
# id
# 1   0.0003    6    6   24.7138    0    0    7  0.056546  0.112860
# 2   0.0000    8    4   38.0658    0    0    7  0.655260  0.886908
# 3   0.0000    6    6   48.3807    0    1    4  0.067855  0.133944
# 4   0.0001    6    4   59.8410    0    0    7  0.133230  0.260102
# 5   0.0000    5    7  175.9250    0    0    3  0.318584  0.627729
#
# [5 rows x 33 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 150 entries, 1 to 150
# Data columns (total 33 columns):
# y      150 non-null float64
# x1     150 non-null float64
# x2     150 non-null float64
# x3     150 non-null int64
# x4     150 non-null int64
# x5     150 non-null int64
# x6     150 non-null int64
# x7     150 non-null int64
# x8     150 non-null float64
# x9     150 non-null int64
# x10    150 non-null float64
# x11    150 non-null float64
# x12    150 non-null float64
# x13    150 non-null int64
# x14    150 non-null int64
# x15    150 non-null int64
# x16    150 non-null int64
# x17    150 non-null int64
# x18    150 non-null int64
# x19    150 non-null int64
# x20    150 non-null int64
# x21    150 non-null float64
# x22    150 non-null float64
# x23    150 non-null float64
# x24    150 non-null float64
# x25    150 non-null int64
# x26    150 non-null int64
# x27    150 non-null float64
# x28    150 non-null int64
# x29    150 non-null int64
# x30    150 non-null int64
# x31    150 non-null float64
# x32    150 non-null float64
# dtypes: float64(14), int64(19)
# memory usage: 39.8 KB

# %%
# test_size = 0.2

# %%
# X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_size)
# data_train, data_test = train_test_split(data, test_size=test_size)

# %%
# data_train.to_csv('datacontinuousstudents_training.csv')
# data_test.to_csv('datacontinuousstudents_test.csv')

# %% [markdown]
# ## Leyendo los datos de entrenamiento

# %%
path = 'continuous_train.csv'
data = pd.read_csv(path, sep = ',', na_filter = False)
data = data.set_index('id')

# %%
X = data.drop(columns = ['y']).copy()
y_train = data[['y']].copy()

# %%
standarscaler = StandardScaler()
X_trained_scaled = standarscaler.fit_transform(X)

# %%
X_trained_scaled = pd.DataFrame(X_trained_scaled, index=X.index, columns=X.columns.values)

# %%
X_trained_scaled.head()
# Out:
#            x1        x2        x3        x4        x5        x6        x7  \
# id
# 84   0.449658 -0.205514 -0.654654 -0.460566 -0.229416 -0.333333 -0.317675
# 14   0.747406 -0.871855  1.527525 -0.460566 -0.229416 -0.333333 -0.317675
# 115  1.137871 -1.030286  1.527525 -0.460566 -0.229416 -0.333333 -0.317675
# 109 -0.338942  0.547033 -0.654654 -0.460566 -0.229416 -0.333333 -0.317675
# 85  -0.605960  0.290748  1.527525 -0.460566 -0.229416 -0.333333 -0.317675
#
#            x8        x9       x10  ...       x23       x24       x25  \
# id                                 ...
# 84   0.592395  0.234124 -0.635548  ...  0.665803 -0.255883  0.649063
# 14  -1.546016  0.234124  2.923038  ... -0.685417 -0.260597 -0.496342
# 115 -0.229548  1.146721 -0.596425  ... -0.692669 -0.210081  0.649063
# 109 -0.447369  1.146721 -0.663149  ... -0.573154  2.538686  0.649063
# 85   0.777699  0.168939 -0.427401  ... -0.494831 -0.263292 -0.496342
#
#           x26       x27       x28       x29       x30       x31       x32
# id
# 84  -2.619694  1.785498 -0.392232 -0.229416  0.454859  1.782964  1.249451
# 14   0.462299  0.632801 -0.392232 -0.229416 -1.364576  0.706199  1.151889
# 115  0.462299 -0.508447 -0.392232 -0.229416 -1.364576 -0.130085  0.044033
# 109 -2.619694 -0.370257 -0.392232 -0.229416  0.000000  1.285682  1.457177
# 85   0.462299 -0.408303 -0.392232 -0.229416  0.909718  0.326116  0.372705
#
# [5 rows x 32 columns]

# %% [markdown]
# ## Leyendo los datos del test

# %%
path = 'continuous_test.csv'
test = pd.read_csv(path, sep = ',', na_filter = False)
test = test.set_index('id')

# %%
X_test = test.drop(columns = ['y']).copy()
y_test = test[['y']].copy()

# %%
X_test_scaled = standarscaler.transform(X_test)

# %%
X_test_scaled = pd.DataFrame(X_test_scaled, index=X_test.index, columns=X_test.columns.values)

# %%
from sklearn.feature_selection import VarianceThreshold
import sklearn
data2 = sklearn.utils.shuffle(X_trained_scaled)
data2.head()
# Out:
#            x1        x2        x3        x4        x5        x6        x7  \
# id
# 42   1.066127 -0.999998 -0.654654 -0.460566 -0.229416  3.000000 -0.317675
# 141 -0.693728 -0.517716  1.527525 -0.460566 -0.229416 -0.333333 -0.317675
# 97   1.101939 -1.074554 -0.654654 -0.460566 -0.229416 -0.333333 -0.317675
# 95   0.467780 -0.412872 -0.654654 -0.460566 -0.229416 -0.333333  3.147871
# 135 -0.638604  0.414231 -0.654654  2.171241 -0.229416 -0.333333 -0.317675
#
#            x8        x9       x10  ...       x23       x24       x25  \
# id                                 ...
# 42   0.367719  0.820793 -0.086597  ... -0.695280 -0.259250 -0.496342
# 141 -1.452839  0.234124 -0.605358  ... -0.693540 -0.241064 -1.641748
# 97  -1.348221  1.146721  0.203624  ... -0.668012 -0.263292  0.649063
# 95  -0.081302  0.755608 -0.656526  ...  2.116231 -0.255209 -0.496342
# 135  0.193707 -1.786624 -0.438533  ...  1.849062 -0.262618  0.649063
#
#           x26       x27       x28       x29       x30       x31       x32
# id
# 42   0.462299 -0.073383 -0.392232 -0.229416  1.364576  0.552529  0.979414
# 141  0.462299  0.488175 -0.392232 -0.229416 -1.364576 -1.032160 -1.085662
# 97   0.462299  2.746135 -0.392232 -0.229416 -1.364576 -0.786475 -0.786255
# 95   0.462299 -0.080909 -0.392232  4.358899  1.364576 -1.223444 -1.332817
# 135  0.462299 -0.394634 -0.392232 -0.229416  0.000000 -0.377944 -0.354768
#
# [5 rows x 32 columns]

# %% [markdown]
# # Feature selection

# %% [markdown]
# ### 1. Mutual information

# %%
from sklearn.feature_selection import mutual_info_classif, mutual_info_regression
from sklearn.feature_selection import SelectKBest, SelectPercentile

# %%
# determine the mutual information
mi = mutual_info_regression(X_trained_scaled, y_train)
mi = pd.Series(mi)
mi.index = X_trained_scaled.columns
mi.sort_values(ascending=False)
# Out:
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# x9     0.152175
# x13    0.117643
# x4     0.098412
# x10    0.095991
# x7     0.093899
# x32    0.060465
# x23    0.060449
# x12    0.059583
# x1     0.059147
# x27    0.046181
# x31    0.038203
# x2     0.032504
# x30    0.025424
# x16    0.023454
# x28    0.013468
# x18    0.011554
# x24    0.010757
# x6     0.008887
# x15    0.000000
# x14    0.000000
# x25    0.000000
# x22    0.000000
# x11    0.000000
# x17    0.000000
# x19    0.000000
# x8     0.000000
# x29    0.000000
# x5     0.000000
# x20    0.000000
# x3     0.000000
# x21    0.000000
# x26    0.000000
# dtype: float64

# %%
# %matplotlib notebook
mi.sort_values(ascending=False).plot.bar()
# Out:
# <div id='e4b8e7f8-91be-4ef0-86aa-6c62471f895c'></div>

# %%
# here I will select the top 10 percentile
sel_ = SelectPercentile(mutual_info_regression, percentile=50).fit(X_trained_scaled, y_train)
X_trained_scaled.columns[sel_.get_support()]
# Out:
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Index(['x1', 'x2', 'x4', 'x7', 'x9', 'x10', 'x12', 'x13', 'x16', 'x23', 'x24',
#        'x27', 'x28', 'x30', 'x31', 'x32'],
#       dtype='object')

# %%
print(X_trained_scaled.shape)
X_trained_scaled.head()
# Out:
# (120, 32)
#            x1        x2        x3        x4        x5        x6        x7  \
# id
# 84   0.449658 -0.205514 -0.654654 -0.460566 -0.229416 -0.333333 -0.317675
# 14   0.747406 -0.871855  1.527525 -0.460566 -0.229416 -0.333333 -0.317675
# 115  1.137871 -1.030286  1.527525 -0.460566 -0.229416 -0.333333 -0.317675
# 109 -0.338942  0.547033 -0.654654 -0.460566 -0.229416 -0.333333 -0.317675
# 85  -0.605960  0.290748  1.527525 -0.460566 -0.229416 -0.333333 -0.317675
#
#            x8        x9       x10  ...       x23       x24       x25  \
# id                                 ...
# 84   0.592395  0.234124 -0.635548  ...  0.665803 -0.255883  0.649063
# 14  -1.546016  0.234124  2.923038  ... -0.685417 -0.260597 -0.496342
# 115 -0.229548  1.146721 -0.596425  ... -0.692669 -0.210081  0.649063
# 109 -0.447369  1.146721 -0.663149  ... -0.573154  2.538686  0.649063
# 85   0.777699  0.168939 -0.427401  ... -0.494831 -0.263292 -0.496342
#
#           x26       x27       x28       x29       x30       x31       x32
# id
# 84  -2.619694  1.785498 -0.392232 -0.229416  0.454859  1.782964  1.249451
# 14   0.462299  0.632801 -0.392232 -0.229416 -1.364576  0.706199  1.151889
# 115  0.462299 -0.508447 -0.392232 -0.229416 -1.364576 -0.130085  0.044033
# 109 -2.619694 -0.370257 -0.392232 -0.229416  0.000000  1.285682  1.457177
# 85   0.462299 -0.408303 -0.392232 -0.229416  0.909718  0.326116  0.372705
#
# [5 rows x 32 columns]

# %% [markdown]
# ### 2. Univariate feature selection

# %%
from sklearn.feature_selection import f_classif, f_regression
from sklearn.feature_selection import SelectKBest, SelectPercentile

# %%
univariate = f_regression(X_trained_scaled, y_train)
univariate = pd.Series(univariate[1])
univariate.index = X_trained_scaled.columns
univariate.sort_values(ascending=False, inplace=True)
# Out:
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
univariate.sort_values(ascending=False).plot.bar()

# %%
# here I will select the top 10 percentile
sel_ = SelectPercentile(f_regression, percentile=50).fit(X_trained_scaled, y_train)
X_trained_scaled.columns[sel_.get_support()]
# Out:
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Index(['x1', 'x3', 'x7', 'x8', 'x12', 'x13', 'x15', 'x18', 'x21', 'x23', 'x24',
#        'x25', 'x26', 'x29', 'x31', 'x32'],
#       dtype='object')

# %%
print(X_trained_scaled.shape)
X_trained_scaled.head()
# Out:
# (120, 32)
#            x1        x2        x3        x4        x5        x6        x7  \
# id
# 84   0.449658 -0.205514 -0.654654 -0.460566 -0.229416 -0.333333 -0.317675
# 14   0.747406 -0.871855  1.527525 -0.460566 -0.229416 -0.333333 -0.317675
# 115  1.137871 -1.030286  1.527525 -0.460566 -0.229416 -0.333333 -0.317675
# 109 -0.338942  0.547033 -0.654654 -0.460566 -0.229416 -0.333333 -0.317675
# 85  -0.605960  0.290748  1.527525 -0.460566 -0.229416 -0.333333 -0.317675
#
#            x8        x9       x10  ...       x23       x24       x25  \
# id                                 ...
# 84   0.592395  0.234124 -0.635548  ...  0.665803 -0.255883  0.649063
# 14  -1.546016  0.234124  2.923038  ... -0.685417 -0.260597 -0.496342
# 115 -0.229548  1.146721 -0.596425  ... -0.692669 -0.210081  0.649063
# 109 -0.447369  1.146721 -0.663149  ... -0.573154  2.538686  0.649063
# 85   0.777699  0.168939 -0.427401  ... -0.494831 -0.263292 -0.496342
#
#           x26       x27       x28       x29       x30       x31       x32
# id
# 84  -2.619694  1.785498 -0.392232 -0.229416  0.454859  1.782964  1.249451
# 14   0.462299  0.632801 -0.392232 -0.229416 -1.364576  0.706199  1.151889
# 115  0.462299 -0.508447 -0.392232 -0.229416 -1.364576 -0.130085  0.044033
# 109 -2.619694 -0.370257 -0.392232 -0.229416  0.000000  1.285682  1.457177
# 85   0.462299 -0.408303 -0.392232 -0.229416  0.909718  0.326116  0.372705
#
# [5 rows x 32 columns]

# %% [markdown]
# ### 3. Step forward

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import r2_score
from mlxtend.feature_selection import SequentialFeatureSelector as SFS

# %%
# find and remove correlated features
def correlation(dataset, threshold):
    col_corr = set()  # Set of all the names of correlated columns
    corr_matrix = dataset.corr()
    for i in range(len(corr_matrix.columns)):
        for j in range(i):
            if abs(corr_matrix.iloc[i, j]) > threshold: # we are interested in absolute coeff value
                colname = corr_matrix.columns[i]  # getting the name of column
                col_corr.add(colname)
    return col_corr

corr_features = correlation(X_trained_scaled, 0.8)
print('correlated features: ', len(set(corr_features)) )
# Out:
# correlated features:  3

# %%
# removed correlated  features
X_trained_scaled_sincorr_forward = X_trained_scaled.drop(labels=corr_features, axis=1)
# X_test.drop(labels=corr_features, axis=1, inplace=True)

X_trained_scaled_sincorr_forward.shape
# , X_test.shape
# Out:
# (120, 29)

# %%
# step forward feature selection

from mlxtend.feature_selection import SequentialFeatureSelector as SFS

sfs1 = SFS(RandomForestRegressor(), 
           k_features=18, 
           forward=True, 
           floating=False, 
           verbose=2,
           scoring='r2',
           cv=5)

sfs1 = sfs1.fit(np.array(X_trained_scaled_sincorr_forward), y_train)
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
# ...
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# [Parallel(n_jobs=1)]: Done  12 out of  12 | elapsed:    0.9s finished
#
# [2019-09-15 13:23:33] Features: 18/18 -- score: 0.14235232674796425

# %%
selected_feat= X_trained_scaled_sincorr_forward.columns[list(sfs1.k_feature_idx_)]
selected_feat
# Out:
# Index(['x1', 'x3', 'x4', 'x5', 'x7', 'x13', 'x14', 'x16', 'x18', 'x19', 'x20',
#        'x23', 'x25', 'x26', 'x28', 'x29', 'x30', 'x31'],
#       dtype='object')

# %%
print(X_trained_scaled.shape)
X_trained_scaled.head()
# Out:
# (120, 32)
#            x1        x2        x3        x4        x5        x6        x7  \
# id
# 84   0.449658 -0.205514 -0.654654 -0.460566 -0.229416 -0.333333 -0.317675
# 14   0.747406 -0.871855  1.527525 -0.460566 -0.229416 -0.333333 -0.317675
# 115  1.137871 -1.030286  1.527525 -0.460566 -0.229416 -0.333333 -0.317675
# 109 -0.338942  0.547033 -0.654654 -0.460566 -0.229416 -0.333333 -0.317675
# 85  -0.605960  0.290748  1.527525 -0.460566 -0.229416 -0.333333 -0.317675
#
#            x8        x9       x10  ...       x23       x24       x25  \
# id                                 ...
# 84   0.592395  0.234124 -0.635548  ...  0.665803 -0.255883  0.649063
# 14  -1.546016  0.234124  2.923038  ... -0.685417 -0.260597 -0.496342
# 115 -0.229548  1.146721 -0.596425  ... -0.692669 -0.210081  0.649063
# 109 -0.447369  1.146721 -0.663149  ... -0.573154  2.538686  0.649063
# 85   0.777699  0.168939 -0.427401  ... -0.494831 -0.263292 -0.496342
#
#           x26       x27       x28       x29       x30       x31       x32
# id
# 84  -2.619694  1.785498 -0.392232 -0.229416  0.454859  1.782964  1.249451
# 14   0.462299  0.632801 -0.392232 -0.229416 -1.364576  0.706199  1.151889
# 115  0.462299 -0.508447 -0.392232 -0.229416 -1.364576 -0.130085  0.044033
# 109 -2.619694 -0.370257 -0.392232 -0.229416  0.000000  1.285682  1.457177
# 85   0.462299 -0.408303 -0.392232 -0.229416  0.909718  0.326116  0.372705
#
# [5 rows x 32 columns]

# %% [markdown]
# ### 4. Step backward feature selection

# %%
# find and remove correlated features
# to reduce the feature space

def correlation(dataset, threshold):
    col_corr = set()  # Set of all the names of correlated columns
    corr_matrix = dataset.corr()
    for i in range(len(corr_matrix.columns)):
        for j in range(i):
            if abs(corr_matrix.iloc[i, j]) > threshold: # we are interested in absolute coeff value
                colname = corr_matrix.columns[i]  # getting the name of column
                col_corr.add(colname)
    return col_corr

corr_features = correlation(X_trained_scaled, 0.6)
print('correlated features: ', len(set(corr_features)) )
# Out:
# correlated features:  9

# %%
# removed correlated  features
X_trained_scaled_sincorr_backward = X_trained_scaled.drop(labels=corr_features, axis=1)
# X_test_scaled.drop(labels=corr_features, axis=1, inplace=True)

X_trained_scaled_sincorr_backward.shape
# , X_test.shape
# Out:
# (120, 23)

# %%
# step backward greedy selection algorithm

sfs1 = SFS(RandomForestRegressor(), 
           k_features=18, 
           forward=False, 
           floating=False, 
           verbose=2,
           scoring='r2',
           cv=5)

sfs1 = sfs1.fit(np.array(X_trained_scaled_sincorr_backward), y_train)
# Out:
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
# ...
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# [Parallel(n_jobs=1)]: Done  19 out of  19 | elapsed:    1.6s finished
#
# [2019-09-15 13:23:43] Features: 18/18 -- score: 0.10151771351522736

# %%
selected_feat= X_trained_scaled_sincorr_backward.columns[list(sfs1.k_feature_idx_)]
selected_feat
# Out:
# Index(['x1', 'x3', 'x4', 'x5', 'x6', 'x7', 'x8', 'x12', 'x13', 'x16', 'x18',
#        'x19', 'x20', 'x21', 'x24', 'x25', 'x28', 'x31'],
#       dtype='object')

# %%
print(X_trained_scaled.shape)
X_trained_scaled.head()
# Out:
# (120, 32)
#            x1        x2        x3        x4        x5        x6        x7  \
# id
# 84   0.449658 -0.205514 -0.654654 -0.460566 -0.229416 -0.333333 -0.317675
# 14   0.747406 -0.871855  1.527525 -0.460566 -0.229416 -0.333333 -0.317675
# 115  1.137871 -1.030286  1.527525 -0.460566 -0.229416 -0.333333 -0.317675
# 109 -0.338942  0.547033 -0.654654 -0.460566 -0.229416 -0.333333 -0.317675
# 85  -0.605960  0.290748  1.527525 -0.460566 -0.229416 -0.333333 -0.317675
#
#            x8        x9       x10  ...       x23       x24       x25  \
# id                                 ...
# 84   0.592395  0.234124 -0.635548  ...  0.665803 -0.255883  0.649063
# 14  -1.546016  0.234124  2.923038  ... -0.685417 -0.260597 -0.496342
# 115 -0.229548  1.146721 -0.596425  ... -0.692669 -0.210081  0.649063
# 109 -0.447369  1.146721 -0.663149  ... -0.573154  2.538686  0.649063
# 85   0.777699  0.168939 -0.427401  ... -0.494831 -0.263292 -0.496342
#
#           x26       x27       x28       x29       x30       x31       x32
# id
# 84  -2.619694  1.785498 -0.392232 -0.229416  0.454859  1.782964  1.249451
# 14   0.462299  0.632801 -0.392232 -0.229416 -1.364576  0.706199  1.151889
# 115  0.462299 -0.508447 -0.392232 -0.229416 -1.364576 -0.130085  0.044033
# 109 -2.619694 -0.370257 -0.392232 -0.229416  0.000000  1.285682  1.457177
# 85   0.462299 -0.408303 -0.392232 -0.229416  0.909718  0.326116  0.372705
#
# [5 rows x 32 columns]

# %% [markdown]
# ### 5. Exhaustive feature selection

# %%
from mlxtend.feature_selection import ExhaustiveFeatureSelector as EFS

# %%
# find and remove correlated features
def correlation(dataset, threshold):
    col_corr = set()  # Set of all the names of correlated columns
    corr_matrix = dataset.corr()
    for i in range(len(corr_matrix.columns)):
        for j in range(i):
            if abs(corr_matrix.iloc[i, j]) > threshold: # we are interested in absolute coeff value
                colname = corr_matrix.columns[i]  # getting the name of column
                col_corr.add(colname)
    return col_corr

corr_features = correlation(X_trained_scaled, 0.8)
print('correlated features: ', len(set(corr_features)) )
# Out:
# correlated features:  3

# %%
X_trained_scaled
# Out:
#            x1        x2        x3        x4        x5        x6        x7  \
# id
# 84   0.449658 -0.205514 -0.654654 -0.460566 -0.229416 -0.333333 -0.317675
# 14   0.747406 -0.871855  1.527525 -0.460566 -0.229416 -0.333333 -0.317675
# 115  1.137871 -1.030286  1.527525 -0.460566 -0.229416 -0.333333 -0.317675
# 109 -0.338942  0.547033 -0.654654 -0.460566 -0.229416 -0.333333 -0.317675
# 85  -0.605960  0.290748  1.527525 -0.460566 -0.229416 -0.333333 -0.317675
# ..        ...       ...       ...       ...       ...       ...       ...
# 60  -1.129831  0.675176  1.527525 -0.460566 -0.229416 -0.333333 -0.317675
# 148  0.625919 -0.774001  1.527525 -0.460566 -0.229416 -0.333333 -0.317675
# 12   0.845827 -0.787980  1.527525 -0.460566 -0.229416 -0.333333 -0.317675
# 56   0.173396 -0.678476  1.527525 -0.460566 -0.229416 -0.333333 -0.317675
# 53  -1.382677  0.915152 -0.654654 -0.460566 -0.229416 -0.333333 -0.317675
#
#            x8        x9       x10  ...       x23       x24       x25  \
# id                                 ...
# 84   0.592395  0.234124 -0.635548  ...  0.665803 -0.255883  0.649063
# 14  -1.546016  0.234124  2.923038  ... -0.685417 -0.260597 -0.496342
# 115 -0.229548  1.146721 -0.596425  ... -0.692669 -0.210081  0.649063
# 109 -0.447369  1.146721 -0.663149  ... -0.573154  2.538686  0.649063
# 85   0.777699  0.168939 -0.427401  ... -0.494831 -0.263292 -0.496342
# ..        ...       ...       ...  ...       ...       ...       ...
# 60  -0.895786  0.168939 -0.133706  ...  1.793076 -0.263292 -0.496342
# 148 -2.002950  0.234124  0.964860  ... -0.656409 -0.263292  0.649063
# 12  -1.213188  0.234124  3.595140  ...  1.807290 -0.261945 -0.496342
# 56  -1.014454  0.234124 -0.434750  ... -0.496861 -0.263292 -0.496342
# 53  -0.264271  0.234124 -0.488510  ...  0.713086 -0.263292 -0.496342
#
#           x26       x27       x28       x29       x30       x31       x32
# id
# 84  -2.619694  1.785498 -0.392232 -0.229416  0.454859  1.782964  1.249451
# 14   0.462299  0.632801 -0.392232 -0.229416 -1.364576  0.706199  1.151889
# 115  0.462299 -0.508447 -0.392232 -0.229416 -1.364576 -0.130085  0.044033
# 109 -2.619694 -0.370257 -0.392232 -0.229416  0.000000  1.285682  1.457177
# 85   0.462299 -0.408303 -0.392232 -0.229416  0.909718  0.326116  0.372705
# ..        ...       ...       ...       ...       ...       ...       ...
# 60   0.462299  1.361263 -0.392232 -0.229416 -0.909718 -0.226674 -0.168016
# 148  1.489630  1.626422 -0.392232 -0.229416 -1.364576 -0.279989 -0.156556
# 12   0.462299  3.230921 -0.392232 -0.229416  0.909718 -0.259331 -0.225074
# 56   0.462299  1.314092 -0.392232 -0.229416  0.909718  1.273380  1.353806
# 53   0.462299 -0.423600 -0.392232 -0.229416  0.909718  1.202654  1.570245
#
# [120 rows x 32 columns]

# %%
# removed correlated  features
X_trained_scaled_sincorr_exhaustive = X_trained_scaled.drop(labels=corr_features, axis=1)
# X_test.drop(labels=corr_features, axis=1, inplace=True)

# X_trained_scaled_sincorr_exhaustive.shape
# , X_test.shape

# %%
# exhaustive search

# in order to shorter search time for the demonstration
# i will ask the algorithm to try all possible 1,2,3 and 4
# feature combinations from a dataset of 4 features

# if you have access to a multicore or distributed computer
# system you can try more greedy searches

efs1 = EFS(RandomForestRegressor(n_jobs=4), 
           min_features=1,
           max_features=5, 
           scoring='r2',
           print_progress=True,
           cv=5)

efs1 = efs1.fit(np.array(X_trained_scaled_sincorr_exhaustive[X_trained_scaled_sincorr_exhaustive.columns[0:5]]), y_train)
# Out:
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# ...
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# Features: 31/31

# %%
selected_feat= X_trained_scaled_sincorr_exhaustive.columns[list(sfs1.k_feature_idx_)]
selected_feat
# Out:
# Index(['x1', 'x3', 'x4', 'x5', 'x6', 'x7', 'x8', 'x12', 'x13', 'x15', 'x16',
#        'x17', 'x18', 'x19', 'x21', 'x22', 'x23', 'x25'],
#       dtype='object')

# %%
print(X_trained_scaled.shape)
X_trained_scaled.head()
# Out:
# (120, 32)
#            x1        x2        x3        x4        x5        x6        x7  \
# id
# 84   0.449658 -0.205514 -0.654654 -0.460566 -0.229416 -0.333333 -0.317675
# 14   0.747406 -0.871855  1.527525 -0.460566 -0.229416 -0.333333 -0.317675
# 115  1.137871 -1.030286  1.527525 -0.460566 -0.229416 -0.333333 -0.317675
# 109 -0.338942  0.547033 -0.654654 -0.460566 -0.229416 -0.333333 -0.317675
# 85  -0.605960  0.290748  1.527525 -0.460566 -0.229416 -0.333333 -0.317675
#
#            x8        x9       x10  ...       x23       x24       x25  \
# id                                 ...
# 84   0.592395  0.234124 -0.635548  ...  0.665803 -0.255883  0.649063
# 14  -1.546016  0.234124  2.923038  ... -0.685417 -0.260597 -0.496342
# 115 -0.229548  1.146721 -0.596425  ... -0.692669 -0.210081  0.649063
# 109 -0.447369  1.146721 -0.663149  ... -0.573154  2.538686  0.649063
# 85   0.777699  0.168939 -0.427401  ... -0.494831 -0.263292 -0.496342
#
#           x26       x27       x28       x29       x30       x31       x32
# id
# 84  -2.619694  1.785498 -0.392232 -0.229416  0.454859  1.782964  1.249451
# 14   0.462299  0.632801 -0.392232 -0.229416 -1.364576  0.706199  1.151889
# 115  0.462299 -0.508447 -0.392232 -0.229416 -1.364576 -0.130085  0.044033
# 109 -2.619694 -0.370257 -0.392232 -0.229416  0.000000  1.285682  1.457177
# 85   0.462299 -0.408303 -0.392232 -0.229416  0.909718  0.326116  0.372705
#
# [5 rows x 32 columns]

# %% [markdown]
# ### 6. Lasso

# %%
from sklearn.linear_model import Lasso, LogisticRegression
from sklearn.feature_selection import SelectFromModel
from sklearn.preprocessing import StandardScaler

# %%
# here, again I will train a Lasso Linear regression and select
# the non zero features in one line.
# bear in mind that the linear regression object from sklearn does
# not allow for regularisation. So If you want to make a regularised
# linear regression you need to import specifically "Lasso"
# that is the l1 version of the linear regression
# alpha is the penalisation here, so I set it high in order
# to force the algorithm to shrink some coefficients

sel_ = SelectFromModel(Lasso(alpha=0.4))
sel_.fit(X_trained_scaled, y_train)
# Out:
# SelectFromModel(estimator=Lasso(alpha=0.4, copy_X=True, fit_intercept=True,
#                                 max_iter=1000, normalize=False, positive=False,
#                                 precompute=False, random_state=None,
#                                 selection='cyclic', tol=0.0001,
#                                 warm_start=False),
#                 max_features=None, norm_order=1, prefit=False, threshold=None)

# %%
sel_.get_support()
# Out:
# array([False, False, False, False, False, False, False, False, False,
#        False, False, False,  True, False, False, False, False, False,
#        False, False, False, False,  True, False,  True, False, False,
#        False, False, False,  True,  True])

# %%
# make a list with the selected features and print the outputs
selected_feat = X_trained_scaled.columns[(sel_.get_support())]

print('total features: {}'.format((X_trained_scaled.shape[1])))
print('selected features: {}'.format(len(selected_feat)))
print('features with coefficients shrank to zero: {}'.format(
    np.sum(sel_.estimator_.coef_ == 0)))
# Out:
# total features: 32
# selected features: 5
# features with coefficients shrank to zero: 27

# %% [markdown]
# ### Linear Regression coefficients

# %%
from sklearn.linear_model import LinearRegression
from sklearn.feature_selection import SelectFromModel
from sklearn.preprocessing import StandardScaler

# %%
# here, again I will train a Linear regression and select
# features with higher coefficients all in one line of code.

# the LinearRegression object from sklearn is a non-regularised
# linear method. It fits by matrix multiplication and not 
# gradient descent.

# therefore I don't need to specify penalty and other parameters

sel_ = SelectFromModel(LinearRegression())
sel_.fit(X_trained_scaled, y_train)
# Out:
# SelectFromModel(estimator=LinearRegression(copy_X=True, fit_intercept=True,
#                                            n_jobs=None, normalize=False),
#                 max_features=None, norm_order=1, prefit=False, threshold=None)

# %%
# let's count the number of variables selected
selected_feat = X_trained_scaled.columns[(sel_.get_support())]
len(selected_feat)
# Out:
# 13

# %%
# and now let's plot the histogram of absolute coefficients

pd.Series(np.abs(sel_.estimator_.coef_).ravel()).hist(bins=50)

# %%
# and now, let's compare the  amount of selected features
# with the amount of features which coefficient is above the
# mean coefficient, to make sure we understand the output of
# sklearn

print('total features: {}'.format((X_trained_scaled.shape[1])))
print('selected features: {}'.format(len(selected_feat)))
print('features with coefficients greater than the mean coefficient: {}'.format(
    np.sum(np.abs(sel_.estimator_.coef_) > np.abs(sel_.estimator_.coef_).mean())))
# Out:
# total features: 32
# selected features: 13
# features with coefficients greater than the mean coefficient: 13

# %%
selected_feat
# Out:
# Index(['x1', 'x6', 'x11', 'x13', 'x15', 'x18', 'x20', 'x21', 'x23', 'x25',
#        'x27', 'x31', 'x32'],
#       dtype='object')

# %% [markdown]
# ### Random forest importance

# %%
# here I will do the model fitting and feature selection
# altogether in one line of code

# first I specify the Random Forest instance, indicating
# the number of trees (the default value in sklearn is 10

# Then I use the selectFromModel object from sklearn
# to automatically select the features

# SelectFrom model will select those features which importance
# is greater than the mean importance of all the features
# by default, but you can alter this threshold if you want to

sel_ = SelectFromModel(RandomForestRegressor(n_estimators=100))
sel_.fit(X_trained_scaled, y_train)
# Out:
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\sklearn\feature_selection\from_model.py:196: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   self.estimator_.fit(X, y, **fit_params)
# SelectFromModel(estimator=RandomForestRegressor(bootstrap=True, criterion='mse',
#                                                 max_depth=None,
#                                                 max_features='auto',
#                                                 max_leaf_nodes=None,
#                                                 min_impurity_decrease=0.0,
#                                                 min_impurity_split=None,
#                                                 min_samples_leaf=1,
#                                                 min_samples_split=2,
#                                                 min_weight_fraction_leaf=0.0,
#                                                 n_estimators=100, n_jobs=None,
#                                                 oob_score=False,
#                                                 random_state=None, verbose=0,
#                                                 warm_start=False),
#                 max_features=None, norm_order=1, prefit=False, threshold=None)

# %%
# let's make a list and count the selected features
selected_feat = X_trained_scaled.columns[(sel_.get_support())]
len(selected_feat)
# Out:
# 14

# %%
# and now, let's compare the  amount of selected features
# with the amount of features which importance is above the
# mean importance, to make sure we understand the output of
# sklearn

print('total features: {}'.format((X_trained_scaled.shape[1])))
print('selected features: {}'.format(len(selected_feat)))
print('features with coefficients greater than the mean coefficient: {}'.format(
    np.sum(sel_.estimator_.feature_importances_ > sel_.estimator_.feature_importances_.mean())))
# Out:
# total features: 32
# selected features: 14
# features with coefficients greater than the mean coefficient: 14

# %%
selected_feat
# Out:
# Index(['x1', 'x2', 'x8', 'x9', 'x10', 'x11', 'x21', 'x22', 'x23', 'x24', 'x25',
#        'x27', 'x31', 'x32'],
#       dtype='object')

# %% [markdown]
# ### Feature selection by random shuffling

# %% [markdown]
# A popular method of feature selection consists in random shuffling the values of a specific variable and determining how that permutation affects the performance metric of the machine learning algorithm. In other words, the idea is to permute the values of each feature, one at the time, and measure how much the permutation decreases the accuracy, or the roc_auc, or the mse of the machine learning model. If the variables are important, this is, highly predictive, a random permutation of their values will decrease dramatically any of these metrics. Contrarily, non-important / non-predictive variables, should have little to no effect on the model performance metric we are assessing.

# %%
from sklearn.metrics import roc_auc_score, mean_squared_error

# %%
# The first step to determine feature importance by feature shuffling
# is to build the machine learning model for which we want to 
# select features

# In this case, I will build Random Forests, but remember that 
# you can use this procedure for any other machine learning algorithm

# I build few and shallow trees to avoid overfitting
rf = RandomForestRegressor(
    n_estimators=100, max_depth=3, random_state=2909, n_jobs=4)

rf.fit(X_trained_scaled, y_train)

# print roc-auc in train and testing sets
print('train rmse: ',
      np.sqrt(mean_squared_error(y_train, (rf.predict(X_trained_scaled)))))
print('test rmse: ',
      np.sqrt(mean_squared_error(y_test, (rf.predict(X_test_scaled)))))
# Out:
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\ipykernel_launcher.py:12: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   if sys.path[0] == '':
# train rmse:  1.505935284648146
# test rmse:  1.998296571086268

# %%
# in this cell, I will shuffle one by one, each feature of the dataset
# and then use the dataset with the shuffled variable to make predictions
# using the random forests I trained in the previous cell

# overall train rmse: using all the features
train_rmse = np.sqrt(
    mean_squared_error(y_train, (rf.predict(X_trained_scaled))))

# dictionary to capture the features, and the drop in rmse that they
# cause when shuffled
feature_dict = {}

# selection  logic
for feature in X_trained_scaled.columns:
    X_train_c = X_trained_scaled.copy()
    X_train_c.reset_index(drop = True, inplace = True)
    # shuffle individual feature
    X_train_c[feature] = X_trained_scaled[feature].sample(frac=1).reset_index(drop=True)
    # make prediction with shuffled feature and calculate roc-auc
    shuff_rmse = np.sqrt( mean_squared_error(y_train, (rf.predict(X_train_c))))

    # store the drop in roc-auc
    feature_dict[feature] = (train_rmse - shuff_rmse)

# %%
# Now I will transform the dictionary into a pandas dataframe
# for easy manipulation

feature_importance = pd.Series(feature_dict).reset_index()
feature_importance.columns = ['feature', 'rmse_drop']
feature_importance.head(15)
# Out:
#    feature  rmse_drop
# 0       x1  -0.003248
# 1       x2  -0.009356
# 2       x3  -0.000933
# 3       x4  -0.007361
# 4       x5  -0.000497
# 5       x6  -0.000875
# 6       x7  -0.004208
# 7       x8  -0.072084
# 8       x9  -0.035168
# 9      x10  -0.012491
# 10     x11  -0.014096
# 11     x12  -0.011089
# 12     x13  -0.001068
# 13     x14  -0.000288
# 14     x15  -0.000586

# %%
# Now I will sort the dataframe according to the drop in performance
# caused by feature shuffling
feature_importance.sort_values(by=['rmse_drop'], ascending=False, inplace=True)

# %%
# visualise the most predictive features
feature_importance
# Out:
#    feature     rmse_drop
# 15     x16  2.220446e-16
# 16     x17  0.000000e+00
# 13     x14 -2.875968e-04
# 17     x18 -2.956938e-04
# 18     x19 -3.730088e-04
# 4       x5 -4.969599e-04
# 14     x15 -5.859641e-04
# 27     x28 -7.642520e-04
# 28     x29 -7.791554e-04
# 5       x6 -8.753054e-04
# 2       x3 -9.333397e-04
# 12     x13 -1.068158e-03
# 19     x20 -1.621819e-03
# 0       x1 -3.248280e-03
# 6       x7 -4.208407e-03
# 30     x31 -6.026516e-03
# 3       x4 -7.361499e-03
# 1       x2 -9.355939e-03
# 11     x12 -1.108905e-02
# 9      x10 -1.249084e-02
# 10     x11 -1.409566e-02
# 23     x24 -2.537485e-02
# 25     x26 -2.749051e-02
# 20     x21 -3.229195e-02
# 8       x9 -3.516831e-02
# 29     x30 -5.053065e-02
# 24     x25 -5.094480e-02
# 26     x27 -5.244708e-02
# 21     x22 -6.561987e-02
# 7       x8 -7.208424e-02
# 31     x32 -1.270655e-01
# 22     x23 -5.989085e-01

# %%
feature_importance.shape[0]

# %%
selected_features = feature_importance[feature_importance.rmse_drop>0]['feature']
selected_features
# Out:
# 15    x16
# Name: feature, dtype: object

# %%
print(X_trained_scaled.shape)
X_trained_scaled.head()

# %% [markdown]
# ### Hybrid method: Recursive feature elimination

# %% [markdown]
# This method consists of the following steps:
#
# 1) Rank the features according to their importance derived from a machine learning algorithm: it can be tree importance, or LASSO / Ridge, or the linear / logistic regression coefficients.
#
# 2) Remove one feature -the least important- and build a machine learning algorithm utilising the remaining features.
#
# 3) Calculate a performance metric of your choice: roc-auc, mse, rmse, accuracy.
#
# 4) If the metric decreases by more of an arbitrarily set threshold, then that feature is important and should be kept. Otherwise, we can remove that feature.
#
# 5) Repeat steps 2-4 until all features have been removed (and therefore evaluated) and the drop in performance assessed.
#
# I call this a hybrid method because:
#
# it combines the importance derived from the machine learning algorithm like embedded methods,
# and it removes as well one feature at a time, and calculates a new metric based on the new subset of features and the machine learning algorithm of choice, like wrapper methods.
# The difference between this method and the step backwards feature selection we learned in previous lectures lies in that it does not remove all features first in order to determine which one to remove. It removes the least important one, based on the machine learning model derived important. And then, it makes an assessment as to whether that feature should be removed or not. So it removes each feature only once during selection, whereas step backward feature selection removes all the features at each step of selection.
#
# This method is therefore faster than wrapper methods and generally better than embedded methods. In practice it works extremely well. It does also account for correlations (depending on how stringent you set the arbitrary performance drop threshold). On the downside, the drop in performance assessed to decide whether the feature should be kept or removed, is set arbitrarily. The smaller the drop the more features will be selected, and vice versa.

# %%
import xgboost as xgb

from sklearn.metrics import r2_score

# %%
# the first step of this procedure consists in building
# a machine learning algorithm using all the available features
# and then determine the importance of the features according
# to the algorithm

# set the seed for reproducibility
seed_val = 434
np.random.seed(seed_val)

# build initial model using all the features
model_all_features = xgb.XGBRegressor(
    nthread=5, max_depth=8, n_estimators=50, learning_rate=0.01)

model_all_features.fit(X_trained_scaled, y_train)

# calculate the r2 in the test set
y_pred_test = model_all_features.predict(X_test_scaled)
r2_score_all = r2_score(y_test, y_pred_test)
print('Test all features xgb R2 = %f' % (r2_score_all))
# Out:
# [13:57:34] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Test all features xgb R2 = -0.278436

# %%
# the second step consist of deriving the importance of 
# each feature and ranking them from the least to the most
# important

# get feature name and importance
features = pd.Series(model_all_features.feature_importances_)
features.index = X_test_scaled.columns

# sort the features by importance
features.sort_values(ascending=True, inplace=True)

# plot
features.plot.bar(figsize=(20,6))

# %%
# view the list of ordered features
features = list(features.index)
features
# Out:
# ['x16',
#  'x29',
#  'x4',
#  'x25',
#  'x20',
#  'x19',
#  'x17',
#  'x31',
#  'x14',
#  'x13',
#  'x28',
#  'x3',
#  'x1',
#  'x10',
#  'x8',
#  'x6',
#  'x5',
#  'x2',
#  'x21',
#  'x11',
#  'x18',
#  'x27',
#  'x32',
#  'x12',
#  'x15',
#  'x7',
#  'x30',
#  'x9',
#  'x26',
#  'x24',
#  'x22',
#  'x23']

# %%
# the final step consists in removing one at a time
# all the features, from the least to the most
# important, and build an xgboost at each round.

# once we build the model, we calculate the new r2
# if the new r2 is smaller than the original one
# (with all the features), then that feature that was removed
# was important, and we should keep it.
# otherwise, we should remove the feature

# recursive feature elimination:

# first we arbitrarily set the drop in r2
# if the drop is below this threshold,
# the feature will be removed
tol = 0.001

print('doing recursive feature elimination')

# we initialise a list where we will collect the
# features we should remove
features_to_remove = []

# set a counter to know how far ahead the loop is going
count = 1

# now we loop over all the features, in order of importance:
# remember that features is the list of ordered features
# by importance
for feature in features:
    print()
    print('testing feature: ', feature, ' which is feature ', count,
          ' out of ', len(features))
    count = count + 1

    # initialise model
    model_int = xgb.XGBRegressor(
        nthread=10, max_depth=4, n_estimators=500, learning_rate=0.05)

    # fit model with all variables minus the removed features
    # and the feature to be evaluated
    model_int.fit(
        X_trained_scaled.drop(features_to_remove + [feature], axis=1), y_train)

    # make a prediction over the test set
    y_pred_test = model_int.predict(
        X_test_scaled.drop(features_to_remove + [feature], axis=1))

    # calculate the new r2
    r2_score_int = r2_score(y_test, y_pred_test)
    print('New Test r2 = {}'.format((r2_score_int)))

    # print the original r2 with all the features
    print('All features Test r2 = {}'.format((r2_score_all)))

    # determine the drop in the r2
    diff_r2 = r2_score_all - r2_score_int

    # compare the drop in r2 with the tolerance
    # we set previously
    if diff_r2 >= tol:
        print('Drop in r2 ={}'.format(diff_r2))
        print('keep: ', feature)
        print
    else:
        print('Drop in r2 = {}'.format(diff_r2))
        print('remove: ', feature)
        print
        # if the drop in the r2 is small and we remove the
        # feature, we need to set the new r2 to the one based on
        # the remaining features
        r2_score_all = r2_score_int
        
        # and append the feature to remove to the collecting
        # list
        features_to_remove.append(feature)

# now the loop is finished, we evaluated all the features
print('DONE!!')
print('total features to remove: ', len(features_to_remove))

# determine the features to keep (those we won't remove)
features_to_keep = [x for x in features if x not in features_to_remove]
print('total features to keep: ', len(features_to_keep))
# Out:
# doing recursive feature elimination
#
# testing feature:  x16  which is feature  1  out of  32
# [13:59:00] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# New Test r2 = -0.7952161163123204
# All features Test r2 = -0.2784358285488726
# Drop in r2 =0.5167802877634478
# keep:  x16
#
# testing feature:  x29  which is feature  2  out of  32
# [13:59:00] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# New Test r2 = -0.8181807600227446
# All features Test r2 = -0.2784358285488726
# Drop in r2 =0.539744931473872
# keep:  x29
#
# testing feature:  x4  which is feature  3  out of  32
# [13:59:01] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# New Test r2 = -0.7233898515234638
# All features Test r2 = -0.2784358285488726
# Drop in r2 =0.4449540229745912
# keep:  x4
#
# testing feature:  x25  which is feature  4  out of  32
# [13:59:01] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# New Test r2 = -0.8370147569225426
# All features Test r2 = -0.2784358285488726
# Drop in r2 =0.55857892837367
# keep:  x25
#
# testing feature:  x20  which is feature  5  out of  32
# [13:59:01] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# New Test r2 = -0.7448486005196018
# All features Test r2 = -0.2784358285488726
# Drop in r2 =0.46641277197072917
# keep:  x20
#
# testing feature:  x19  which is feature  6  out of  32
# [13:59:01] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# New Test r2 = -0.7015823710048859
# All features Test r2 = -0.2784358285488726
# Drop in r2 =0.42314654245601324
# keep:  x19
#
# testing feature:  x17  which is feature  7  out of  32
# [13:59:02] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# New Test r2 = -0.8181807600227446
# All features Test r2 = -0.2784358285488726
# Drop in r2 =0.539744931473872
# keep:  x17
#
# testing feature:  x31  which is feature  8  out of  32
# [13:59:02] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# New Test r2 = -0.6946189066420541
# All features Test r2 = -0.2784358285488726
# Drop in r2 =0.41618307809318145
# keep:  x31
#
# testing feature:  x14  which is feature  9  out of  32
# [13:59:02] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# New Test r2 = -0.8083274004326502
# All features Test r2 = -0.2784358285488726
# Drop in r2 =0.5298915718837776
# keep:  x14
#
# testing feature:  x13  which is feature  10  out of  32
# [13:59:03] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# New Test r2 = -0.7790671900959383
# All features Test r2 = -0.2784358285488726
# Drop in r2 =0.5006313615470657
# keep:  x13
#
# testing feature:  x28  which is feature  11  out of  32
# [13:59:03] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# New Test r2 = -0.7679306300494715
# All features Test r2 = -0.2784358285488726
# Drop in r2 =0.4894948015005989
# keep:  x28
#
# testing feature:  x3  which is feature  12  out of  32
# [13:59:03] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# New Test r2 = -0.752416192942875
# All features Test r2 = -0.2784358285488726
# Drop in r2 =0.4739803643940024
# keep:  x3
#
# testing feature:  x1  which is feature  13  out of  32
# [13:59:04] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# New Test r2 = -0.4756193110387965
# All features Test r2 = -0.2784358285488726
# Drop in r2 =0.1971834824899239
# keep:  x1
#
# testing feature:  x10  which is feature  14  out of  32
# [13:59:04] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# New Test r2 = -0.7777281644709089
# All features Test r2 = -0.2784358285488726
# Drop in r2 =0.49929233592203626
# keep:  x10
#
# testing feature:  x8  which is feature  15  out of  32
# [13:59:04] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# New Test r2 = -0.6190301707407457
# All features Test r2 = -0.2784358285488726
# Drop in r2 =0.3405943421918731
# keep:  x8
#
# testing feature:  x6  which is feature  16  out of  32
# [13:59:04] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# New Test r2 = -0.7856043531318668
# All features Test r2 = -0.2784358285488726
# Drop in r2 =0.5071685245829942
# keep:  x6
#
# testing feature:  x5  which is feature  17  out of  32
# [13:59:05] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# New Test r2 = -0.8181807600227446
# All features Test r2 = -0.2784358285488726
# Drop in r2 =0.539744931473872
# keep:  x5
#
# testing feature:  x2  which is feature  18  out of  32
# [13:59:05] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# New Test r2 = -0.6981609266113937
# All features Test r2 = -0.2784358285488726
# Drop in r2 =0.4197250980625211
# keep:  x2
#
# testing feature:  x21  which is feature  19  out of  32
# [13:59:05] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# New Test r2 = -0.6630335975280326
# All features Test r2 = -0.2784358285488726
# Drop in r2 =0.38459776897916
# keep:  x21
#
# testing feature:  x11  which is feature  20  out of  32
# [13:59:06] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# New Test r2 = -0.822558310178316
# All features Test r2 = -0.2784358285488726
# Drop in r2 =0.5441224816294434
# keep:  x11
#
# testing feature:  x18  which is feature  21  out of  32
# [13:59:06] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# New Test r2 = -0.6068802568455298
# All features Test r2 = -0.2784358285488726
# Drop in r2 =0.3284444282966572
# keep:  x18
#
# testing feature:  x27  which is feature  22  out of  32
# [13:59:06] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# New Test r2 = -0.8700968141761758
# All features Test r2 = -0.2784358285488726
# Drop in r2 =0.5916609856273032
# keep:  x27
#
# testing feature:  x32  which is feature  23  out of  32
# [13:59:06] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# New Test r2 = -0.5943386521140506
# All features Test r2 = -0.2784358285488726
# Drop in r2 =0.31590282356517796
# keep:  x32
#
# testing feature:  x12  which is feature  24  out of  32
# [13:59:07] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# New Test r2 = -0.6017076606599661
# All features Test r2 = -0.2784358285488726
# Drop in r2 =0.32327183211109345
# keep:  x12
#
# testing feature:  x15  which is feature  25  out of  32
# [13:59:07] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# New Test r2 = -0.829201128475878
# All features Test r2 = -0.2784358285488726
# Drop in r2 =0.5507652999270054
# keep:  x15
#
# testing feature:  x7  which is feature  26  out of  32
# [13:59:07] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# New Test r2 = -0.6933522283767601
# All features Test r2 = -0.2784358285488726
# Drop in r2 =0.4149163998278875
# keep:  x7
#
# testing feature:  x30  which is feature  27  out of  32
# [13:59:08] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# New Test r2 = -0.7435139046041899
# All features Test r2 = -0.2784358285488726
# Drop in r2 =0.46507807605531726
# keep:  x30
#
# testing feature:  x9  which is feature  28  out of  32
# [13:59:08] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# New Test r2 = -0.674771521413496
# All features Test r2 = -0.2784358285488726
# Drop in r2 =0.39633569286462333
# keep:  x9
#
# testing feature:  x26  which is feature  29  out of  32
# [13:59:08] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# New Test r2 = -0.8797169496492887
# All features Test r2 = -0.2784358285488726
# Drop in r2 =0.6012811211004161
# keep:  x26
#
# testing feature:  x24  which is feature  30  out of  32
# [13:59:08] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# New Test r2 = -0.6013920404840079
# All features Test r2 = -0.2784358285488726
# Drop in r2 =0.32295621193513524
# keep:  x24
#
# testing feature:  x22  which is feature  31  out of  32
# [13:59:09] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# New Test r2 = -0.6396643012472951
# All features Test r2 = -0.2784358285488726
# Drop in r2 =0.3612284726984225
# keep:  x22
#
# testing feature:  x23  which is feature  32  out of  32
# [13:59:09] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# New Test r2 = -0.5542366131712326
# All features Test r2 = -0.2784358285488726
# Drop in r2 =0.27580078462236
# keep:  x23
# DONE!!
# total features to remove:  0
# total features to keep:  32

# %%
# capture the 23 selected features
seed_val = 1000000000
np.random.seed(seed_val)

# build initial model
final_xgb = xgb.XGBRegressor(nthread=10, max_depth=4, n_estimators=500, learning_rate=0.05)

# fit the model with the selected features
final_xgb.fit(X_trained_scaled[features_to_keep], y_train)

# make predictions
y_pred_test = final_xgb.predict(X_test_scaled[features_to_keep])

# calculate roc-auc
r2_score_final = r2_score(y_test, y_pred_test)
print('Test selected features r2 = %f' % (r2_score_final))
print('Test all features r2 = %f' % (r2_score_all))
# Out:
# [13:59:29] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Test selected features r2 = -0.749559
# Test all features r2 = -0.278436

# %%
features_to_keep

# %%
print(X_trained_scaled.shape)
X_trained_scaled.head()

# %% [markdown]
# ### Hybrid method: Recursive feature addition

# %% [markdown]
# This method consists of the following steps:
#
# 1) Rank the features according to their importance derived from a machine learning algorithm: it can be tree importance, or LASSO / Ridge, or the linear / logistic regression coefficients.
#
# 2) Build a machine learning model with only 1 feature, the most important one, and calculate the model metric for performance.
#
# 3) Add one feature -the most important- and build a machine learning algorithm utilising the added and any feature from previous rounds.
#
# 4) Calculate a performance metric of your choice: roc-auc, mse, rmse, accuracy.
#
# 5) If the metric increases by more than an arbitrarily set threshold, then that feature is important and should be kept. Otherwise, we can remove that feature.
#
# 6) Repeat steps 2-5 until all features have been removed (and therefore evaluated) and the drop in performance assessed.
#
# I call this a hybrid method because:
#
# it combines the importance derived from the machine learning algorithm like embedded methods,
# and it adds as well one feature at a time, and calculates a new metric based on the new subset of features and the machine learning algorithm of choice, like wrapper methods.
# The difference between this method and the step forward feature selection we learned in previous lectures lies in that it does not add all possible features first, in order to determine which one to keep. It adds the most important one, based on the machine learning model derived important. And then, it makes an assessment as to whether that feature should be kept or not. And then it moves to the next feature.
#
# This method is therefore faster than wrapper methods and generally better than embedded methods. In practice it works extremely well. It does also account for correlations (depending on how stringent you set the arbitrary performance drop threshold). On the downside, the increase in performance assessed to decide whether the feature should be kept or removed, is set arbitrarily. The smaller the increase the more features will be selected, and vice versa

# %%
import xgboost as xgb

from sklearn.metrics import roc_auc_score, r2_score

# %%
# the first step of this procedure consists in building
# a machine learning algorithm using all the available features
# and then determine the importance of the features according
# to the algorithm

# set the seed for reproducibility
seed_val = 1000000000
np.random.seed(seed_val)

# build initial model using all the features
model_all_features = xgb.XGBRegressor(
    nthread=10, max_depth=4, n_estimators=500, learning_rate=0.05)

model_all_features.fit(X_trained_scaled, y_train)

# calculate the roc-auc in the test set
y_pred_test = model_all_features.predict(X_test_scaled)
r2_score_all = r2_score(y_test, y_pred_test)
print('Test all features xgb R2 = %f' % (r2_score_all))
# Out:
# [15:06:22] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Test all features xgb R2 = -0.818181

# %%
# the second step consist of deriving the importance of 
# each feature and ranking them from the most to the least
# important

# get feature name and importance
features = pd.Series(model_all_features.feature_importances_)
features.index = X_trained_scaled.columns

# sort the features by importance
features.sort_values(ascending=False, inplace=True)

# plot
features.plot.bar(figsize=(20,6))

# %%
# view the list of ordered features
features = list(features.index)
features
# Out:
# ['x23',
#  'x26',
#  'x18',
#  'x4',
#  'x24',
#  'x9',
#  'x32',
#  'x22',
#  'x25',
#  'x7',
#  'x8',
#  'x21',
#  'x13',
#  'x27',
#  'x28',
#  'x2',
#  'x30',
#  'x12',
#  'x19',
#  'x20',
#  'x10',
#  'x31',
#  'x3',
#  'x11',
#  'x15',
#  'x1',
#  'x6',
#  'x17',
#  'x5',
#  'x16',
#  'x14',
#  'x29']

# %%
# next, we need to build a machine learning
# algorithm using only the most important feature

# set the seed for reproducibility
seed_val = 1000000000
np.random.seed(seed_val)

# build initial model using all the features
model_one_feature = xgb.XGBRegressor(
    nthread=10, max_depth=4, n_estimators=500, learning_rate=0.05)

# train using only the most important feature
model_one_feature.fit(X_trained_scaled[features[0]].to_frame(), y_train)

# calculate the roc-auc in the test set
y_pred_test = model_one_feature.predict(X_test[features[0]].to_frame())
r2_score_first = r2_score(y_test, y_pred_test)
print('Test one feature xgb R2=%f' % (r2_score_first))
# Out:
# [15:06:56] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Test one feature xgb R2=-0.740700

# %%
# the final step consists in adding one at a time
# all the features, from the most to the least
# important, and build an xgboost at each round.

# once we build the model, we calculate the new r2
# if the new r2 is bigger than the original one
# (with one feature), then that feature that was added
# was important, and we should keep it.
# otherwise, we should remove the feature

# recursive feature addition:

# first we arbitrarily set the increase in r2
# if the increase is above this threshold,
# the feature will be kept
tol = 0.001

print('doing recursive feature addition')

# we initialise a list where we will collect the
# features we should keep
features_to_keep = [features[0]]

# set a counter to know how far ahead the loop is going
count = 1

# now we loop over all the features, in order of importance:
# remember that features is the list of ordered features
# by importance
for feature in features[1:]:
    print()
    print('testing feature: ', feature, ' which is feature ', count,
          ' out of ', len(features))
    count = count + 1

    # initialise model
    model_int = xgb.XGBRegressor(
        nthread=10, max_depth=4, n_estimators=500, learning_rate=0.05)

    # fit model with the selected features
    # and the feature to be evaluated
    model_int.fit(
        X_trained_scaled[features_to_keep + [feature] ], y_train)

    # make a prediction over the test set
    y_pred_test = model_int.predict(
        X_test_scaled[features_to_keep + [feature] ])

    # calculate the new r2
    r2_score_int = r2_score(y_test, y_pred_test)
    print('New Test r2_score={}'.format((r2_score_int)))

    # print the original roc-auc with all the features
    print('All features Test r2_score={}'.format((r2_score_first)))

    # determine the drop in the roc-auc
    diff_r2 = r2_score_int - r2_score_first

    # compare the increase in r2 with the tolerance
    # we set previously
    if diff_r2 >= tol:
        print('Increase in r2 = {}'.format(diff_r2))
        print('keep: ', feature)
        print
        # if the increase in the r2 is bigger than the threshold
        # we keep the feature and re-adjust the r2 to the new value
        # considering the added feature
        r2_score_first = r2_score_int
        
        # and we append the feature to keep to the list
        features_to_keep.append(feature)
    else:
        # we ignore the feature
        print('Increase in r2 = {}'.format(diff_r2))
        print('remove: ', feature)
        print


# now the loop is finished, we evaluated all the features
print('DONE!!')
print('total features to keep: ', len(features_to_keep))
# Out:
# doing recursive feature addition
#
# testing feature:  x26  which is feature  1  out of  32
# [15:07:00] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# New Test r2_score=-0.3895132732835176
# All features Test r2_score=-0.7406998032549057
# Increase in r2 = 0.3511865299713881
# keep:  x26
#
# testing feature:  x18  which is feature  2  out of  32
# [15:07:00] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# New Test r2_score=-0.7552889491473209
# All features Test r2_score=-0.3895132732835176
# Increase in r2 = -0.36577567586380333
# remove:  x18
#
# testing feature:  x4  which is feature  3  out of  32
# [15:07:00] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# New Test r2_score=-0.24464359837940663
# All features Test r2_score=-0.3895132732835176
# Increase in r2 = 0.14486967490411096
# keep:  x4
#
# testing feature:  x24  which is feature  4  out of  32
# [15:07:00] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# New Test r2_score=-0.6222913495777278
# All features Test r2_score=-0.24464359837940663
# Increase in r2 = -0.37764775119832117
# remove:  x24
#
# testing feature:  x9  which is feature  5  out of  32
# [15:07:00] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# New Test r2_score=-0.46722275274445346
# All features Test r2_score=-0.24464359837940663
# Increase in r2 = -0.22257915436504683
# remove:  x9
#
# testing feature:  x32  which is feature  6  out of  32
# [15:07:00] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# New Test r2_score=-0.8992225307954445
# All features Test r2_score=-0.24464359837940663
# Increase in r2 = -0.6545789324160378
# remove:  x32
#
# testing feature:  x22  which is feature  7  out of  32
# [15:07:01] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# New Test r2_score=-0.41455091398724586
# All features Test r2_score=-0.24464359837940663
# Increase in r2 = -0.16990731560783923
# remove:  x22
#
# testing feature:  x25  which is feature  8  out of  32
# [15:07:01] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# New Test r2_score=-0.548058615566944
# All features Test r2_score=-0.24464359837940663
# Increase in r2 = -0.3034150171875374
# remove:  x25
#
# testing feature:  x7  which is feature  9  out of  32
# [15:07:01] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# New Test r2_score=-0.15123039549926487
# All features Test r2_score=-0.24464359837940663
# Increase in r2 = 0.09341320288014177
# keep:  x7
#
# testing feature:  x8  which is feature  10  out of  32
# [15:07:01] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# New Test r2_score=-0.9367826258956597
# All features Test r2_score=-0.15123039549926487
# Increase in r2 = -0.7855522303963949
# remove:  x8
#
# testing feature:  x21  which is feature  11  out of  32
# [15:07:01] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# New Test r2_score=-0.7740551663747297
# All features Test r2_score=-0.15123039549926487
# Increase in r2 = -0.6228247708754648
# remove:  x21
#
# testing feature:  x13  which is feature  12  out of  32
# [15:07:01] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# New Test r2_score=-0.368198831976972
# All features Test r2_score=-0.15123039549926487
# Increase in r2 = -0.21696843647770714
# remove:  x13
#
# testing feature:  x27  which is feature  13  out of  32
# [15:07:02] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# New Test r2_score=-0.4513715075018525
# All features Test r2_score=-0.15123039549926487
# Increase in r2 = -0.30014111200258764
# remove:  x27
#
# testing feature:  x28  which is feature  14  out of  32
# [15:07:02] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# New Test r2_score=-0.3298325834152791
# All features Test r2_score=-0.15123039549926487
# Increase in r2 = -0.17860218791601423
# remove:  x28
#
# testing feature:  x2  which is feature  15  out of  32
# [15:07:02] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# New Test r2_score=-0.8566968808435693
# All features Test r2_score=-0.15123039549926487
# Increase in r2 = -0.7054664853443045
# remove:  x2
#
# testing feature:  x30  which is feature  16  out of  32
# [15:07:02] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# New Test r2_score=-0.3159899581745802
# All features Test r2_score=-0.15123039549926487
# Increase in r2 = -0.16475956267531533
# remove:  x30
#
# testing feature:  x12  which is feature  17  out of  32
# [15:07:02] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# New Test r2_score=-0.19813312169697261
# All features Test r2_score=-0.15123039549926487
# Increase in r2 = -0.046902726197707745
# remove:  x12
#
# testing feature:  x19  which is feature  18  out of  32
# [15:07:02] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# New Test r2_score=-0.34909651935704633
# All features Test r2_score=-0.15123039549926487
# Increase in r2 = -0.19786612385778146
# remove:  x19
#
# testing feature:  x20  which is feature  19  out of  32
# [15:07:03] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# New Test r2_score=-0.13155682246964995
# All features Test r2_score=-0.15123039549926487
# Increase in r2 = 0.01967357302961492
# keep:  x20
#
# testing feature:  x10  which is feature  20  out of  32
# [15:07:03] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# New Test r2_score=-0.25177766287410774
# All features Test r2_score=-0.13155682246964995
# Increase in r2 = -0.1202208404044578
# remove:  x10
#
# testing feature:  x31  which is feature  21  out of  32
# [15:07:03] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# New Test r2_score=-0.4046422349145997
# All features Test r2_score=-0.13155682246964995
# Increase in r2 = -0.27308541244494977
# remove:  x31
#
# testing feature:  x3  which is feature  22  out of  32
# [15:07:03] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# New Test r2_score=-0.32701716917123735
# All features Test r2_score=-0.13155682246964995
# Increase in r2 = -0.1954603467015874
# remove:  x3
#
# testing feature:  x11  which is feature  23  out of  32
# [15:07:03] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# New Test r2_score=-0.3366958650815146
# All features Test r2_score=-0.13155682246964995
# Increase in r2 = -0.20513904261186466
# remove:  x11
#
# testing feature:  x15  which is feature  24  out of  32
# [15:07:03] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# New Test r2_score=-0.3315783022443246
# All features Test r2_score=-0.13155682246964995
# Increase in r2 = -0.20002147977467466
# remove:  x15
#
# testing feature:  x1  which is feature  25  out of  32
# [15:07:04] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# New Test r2_score=-1.0322954289987019
# All features Test r2_score=-0.13155682246964995
# Increase in r2 = -0.9007386065290519
# remove:  x1
#
# testing feature:  x6  which is feature  26  out of  32
# [15:07:04] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# New Test r2_score=-0.24320243431823685
# All features Test r2_score=-0.13155682246964995
# Increase in r2 = -0.1116456118485869
# remove:  x6
#
# testing feature:  x17  which is feature  27  out of  32
# [15:07:04] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# New Test r2_score=-0.1817740990094261
# All features Test r2_score=-0.13155682246964995
# Increase in r2 = -0.050217276539776146
# remove:  x17
#
# testing feature:  x5  which is feature  28  out of  32
# [15:07:04] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# New Test r2_score=-0.17787585735050615
# All features Test r2_score=-0.13155682246964995
# Increase in r2 = -0.0463190348808562
# remove:  x5
#
# testing feature:  x16  which is feature  29  out of  32
# [15:07:04] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# New Test r2_score=-0.17242638293065782
# All features Test r2_score=-0.13155682246964995
# Increase in r2 = -0.04086956046100787
# remove:  x16
#
# testing feature:  x14  which is feature  30  out of  32
# [15:07:04] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# New Test r2_score=-0.23957610012742458
# All features Test r2_score=-0.13155682246964995
# Increase in r2 = -0.10801927765777464
# remove:  x14
#
# testing feature:  x29  which is feature  31  out of  32
# [15:07:04] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# New Test r2_score=-0.12614005567946873
# All features Test r2_score=-0.13155682246964995
# Increase in r2 = 0.0054167667901812155
# keep:  x29
# DONE!!
# total features to keep:  6

# %%
# capture the 36 selected features
seed_val = 1000000000
np.random.seed(seed_val)

# build initial model
final_xgb = xgb.XGBRegressor(
    nthread=10, max_depth=4, n_estimators=500, learning_rate=0.05)

# fit the model with the selected features
final_xgb.fit(X_trained_scaled[features_to_keep], y_train)

# make predictions
y_pred_test = final_xgb.predict(X_test_scaled[features_to_keep])

# calculate roc-auc
r2_score_final = r2_score(y_test, y_pred_test)
print('Test selected features r2_score=%f' % (r2_score_final))
# Out:
# [15:07:29] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Test selected features r2_score=-0.126140

# %%
features_to_keep

# %%
print(X_trained_scaled.shape)
X_trained_scaled.head()

# %%
def svr_main(X, Y):
    X_train = X[:TRAIN_SIZE]
    Y_train = Y[:TRAIN_SIZE]
    X_test = X[TRAIN_SIZE:]
    Y_test = Y[TRAIN_SIZE:]

    clf = SVR(kernel='rbf', C=1e3, gamma=0.00001)
    #clf.fit(X_train,Y_train)
    #y_pred = clf.predict(X_test)
    #plt.plot(X_test, y_pred, linestyle='-', color='red') 

    #clf = GradientBoostingRegressor(n_estimators=100,max_depth=1)
    #clf = DecisionTreeRegressor(max_depth=25)
    #clf = ExtraTreesRegressor(n_estimators=2000,max_depth=14)
    #clf = xgb.XGBRegressor(n_estimators=2000,max_depth=25)
    #clf = RandomForestRegressor(n_estimators=1000,max_depth=26,n_jobs=7)
    predict_list = []
    for i in xrange(TEST_SIZE):
        X = [ [x] for x in xrange(i, TRAIN_SIZE+i)]
        clf.fit(X, Y[i:TRAIN_SIZE+i])
        y_pred = clf.predict([TRAIN_SIZE+1+i])
        predict_list.append(y_pred)

    print("mean_squared_error:%s"%)mean_squared_error(Y_test, predict_list)
    print("sqrt of mean_squared_error:%s"%)np.sqrt(mean_squared_error(Y_test, predict_list))
    origin_data = Y_test
    print "origin data:%s"%origin_data
    plt.plot([ x for x in xrange(TRAIN_SIZE+1, TRAIN_SIZE+TEST_SIZE+1)], predict_list, linestyle='-', color='red', label='prediction model')  
    plt.plot(X_test, Y_test, linestyle='-', color='blue', label='actual model') 
    plt.legend(loc=1, prop={'size': 12})
    plt.show()

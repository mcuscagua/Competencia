# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import GridSearchCV,train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error, r2_score

# %% [markdown]
# # Leer datos de entrenamiento

# %%
path = 'continuous_train.csv'
data = pd.read_csv(path, sep = ',', na_filter = False)
data = data.set_index('Unnamed: 0')

X = data.drop(columns = ['y']).copy()
y_train = data[['y']].copy()

# %% [markdown]
# # Leer datos de validación

# %%
path = 'continuous_test.csv'
test = pd.read_csv(path, sep = ',', na_filter = False)
test = test.set_index('Unnamed: 0')

X_test = test.drop(columns = ['y']).copy()
y_test = test[['y']].copy()

# %% [markdown]
# # Leer variables

# %%
path = 'variablesToProof.csv'
variablesTorun = pd.read_csv(path, sep = ',')

# %%
def calculated_metrics(variablesSelected,X_trained_scaled,y_train,X_test_scaled,y_test):
    X_trained_scaled_aux = X_trained_scaled[variablesSelected].copy()
    X_test_scaled_aux = X_test_scaled[variablesSelected].copy()
    ## Regresion para cada cantidad de variables
    regr = LinearRegression()

    # Train the model using the training sets
    regr.fit(X_trained_scaled_aux,  y_train['y'].values)

    # Make predictions using the testing set
    y_pred = regr.predict(X_test_scaled_aux)

    y_pred = pd.DataFrame(y_pred, index=y_test.index, columns=["y_pred"])

    total = y_pred.join(y_test)
    total['y_menor_-1'] = (total['y']<-1).astype(int)
    total['y_pred_menor_-1'] = (total['y_pred']<-1).astype(int)
    total['good_class'] = (total['y_menor_-1']==total['y_pred_menor_-1']).astype(int)
    mse = mean_squared_error(y_test, y_pred)
    accuray =total['good_class'].sum()/len(total)
    r2 = r2_score(y_test, y_pred)
    return mse,accuray,r2

# %%
resultados =  pd.DataFrame({'Modelo':  variablesTorun.columns[1:]})

# %%
resultados =  pd.DataFrame()
for i in variablesTorun.columns[1:]:
    print(i)
    mse = []
    accuray = []
    r2 = []
    if len(list(variablesTorun[variablesTorun[i]==1]['VariableName']))>0:
        for j in range(1,1000):
            X_train, X_test_aux, y_train_aux, y_test_aux = train_test_split(X, y_train, test_size=0.2)
            standarscaler = StandardScaler()
            X_trained_scaled_aux = standarscaler.fit_transform(X_train)
            X_trained_scaled_aux = pd.DataFrame(X_trained_scaled_aux, index=X_train.index, columns=X_train.columns.values)

            X_test_scaled_aux = standarscaler.transform(X_test_aux)

            X_test_scaled_aux = pd.DataFrame(X_test_scaled_aux, index=X_test_aux.index, columns=X_test_aux.columns.values)


            variablesSelected = list(variablesTorun[variablesTorun[i]==1]['VariableName'])
            mse_aux,accuray_aux,r2_aux= calculated_metrics(variablesSelected,X_trained_scaled_aux,y_train_aux,X_test_scaled_aux,y_test_aux)
            mse.append(mse_aux)
            accuray.append(accuray_aux)
            r2.append(r2_aux)

        auxRes= pd.DataFrame({'Modelo': i, 'Median: Mean squared error': [np.median(np.asarray(mse))], 'Median: R2': [np.median(np.asarray(r2))],'Median: Accuray': [np.median(np.asarray(accuray))]})
        resultados = pd.concat([resultados,auxRes])
        resultados.to_csv('ResultadosCV_scores.csv')
    else:
        print(f"El conjunto de variables {i} no tiene variables")
#     break
# resultado_scores_ranking_cv.reset_index(inplace = True,drop = True)
# Out:
# Cantidad de variables: 1 Iteracion: 1
# Cantidad de variables: 1 Iteracion: 2
# Cantidad de variables: 1 Iteracion: 4
# Cantidad de variables: 1 Iteracion: 5
# Cantidad de variables: 1 Iteracion: 7
# Cantidad de variables: 1 Iteracion: 8
# Cantidad de variables: 1 Iteracion: 42
# Cantidad de variables: 2 Iteracion: 1
# Cantidad de variables: 2 Iteracion: 2
# Cantidad de variables: 2 Iteracion: 3
# Cantidad de variables: 2 Iteracion: 4
# Cantidad de variables: 2 Iteracion: 6
# Cantidad de variables: 2 Iteracion: 7
# Cantidad de variables: 2 Iteracion: 9
# Cantidad de variables: 2 Iteracion: 13
# Cantidad de variables: 2 Iteracion: 15
# Cantidad de variables: 2 Iteracion: 20
# Cantidad de variables: 2 Iteracion: 22
# Cantidad de variables: 2 Iteracion: 29
# Cantidad de variables: 2 Iteracion: 39
# Cantidad de variables: 2 Iteracion: 53
# Cantidad de variables: 2 Iteracion: 55
# Cantidad de variables: 2 Iteracion: 56
# Cantidad de variables: 2 Iteracion: 63
# Cantidad de variables: 2 Iteracion: 64
# Cantidad de variables: 2 Iteracion: 71
# Cantidad de variables: 2 Iteracion: 83
# Cantidad de variables: 2 Iteracion: 85
# Cantidad de variables: 2 Iteracion: 87
# Cantidad de variables: 3 Iteracion: 1
# Cantidad de variables: 3 Iteracion: 2
# Cantidad de variables: 3 Iteracion: 3
# Cantidad de variables: 3 Iteracion: 4
# Cantidad de variables: 3 Iteracion: 5
# Cantidad de variables: 3 Iteracion: 6
# Cantidad de variables: 3 Iteracion: 7
# Cantidad de variables: 3 Iteracion: 8
# Cantidad de variables: 3 Iteracion: 9
# Cantidad de variables: 3 Iteracion: 10
# Cantidad de variables: 3 Iteracion: 11
# Cantidad de variables: 3 Iteracion: 13
# Cantidad de variables: 3 Iteracion: 15
# Cantidad de variables: 3 Iteracion: 16
# Cantidad de variables: 3 Iteracion: 17
# Cantidad de variables: 3 Iteracion: 18
# Cantidad de variables: 3 Iteracion: 20
# Cantidad de variables: 3 Iteracion: 21
# Cantidad de variables: 3 Iteracion: 22
# Cantidad de variables: 3 Iteracion: 23
# Cantidad de variables: 3 Iteracion: 24
# Cantidad de variables: 3 Iteracion: 27
# Cantidad de variables: 3 Iteracion: 28
# Cantidad de variables: 3 Iteracion: 29
# Cantidad de variables: 3 Iteracion: 30
# Cantidad de variables: 3 Iteracion: 31
# Cantidad de variables: 3 Iteracion: 34
# Cantidad de variables: 3 Iteracion: 38
# Cantidad de variables: 3 Iteracion: 39
# Cantidad de variables: 3 Iteracion: 40
# Cantidad de variables: 3 Iteracion: 47
# Cantidad de variables: 3 Iteracion: 48
# Cantidad de variables: 3 Iteracion: 53
# Cantidad de variables: 3 Iteracion: 54
# Cantidad de variables: 3 Iteracion: 55
# Cantidad de variables: 3 Iteracion: 56
# Cantidad de variables: 3 Iteracion: 57
# Cantidad de variables: 3 Iteracion: 59
# Cantidad de variables: 3 Iteracion: 63
# Cantidad de variables: 3 Iteracion: 66
# Cantidad de variables: 3 Iteracion: 73
# Cantidad de variables: 3 Iteracion: 76
# Cantidad de variables: 3 Iteracion: 77
# Cantidad de variables: 3 Iteracion: 78
# Cantidad de variables: 3 Iteracion: 80
# Cantidad de variables: 3 Iteracion: 89
# Cantidad de variables: 3 Iteracion: 90
# Cantidad de variables: 3 Iteracion: 95
# Cantidad de variables: 3 Iteracion: 96
# Cantidad de variables: 3 Iteracion: 97
# Cantidad de variables: 4 Iteracion: 1
# Cantidad de variables: 4 Iteracion: 2
# Cantidad de variables: 4 Iteracion: 3
# Cantidad de variables: 4 Iteracion: 4
# Cantidad de variables: 4 Iteracion: 5
# Cantidad de variables: 4 Iteracion: 6
# Cantidad de variables: 4 Iteracion: 7
# Cantidad de variables: 4 Iteracion: 8
# Cantidad de variables: 4 Iteracion: 9
# Cantidad de variables: 4 Iteracion: 12
# Cantidad de variables: 4 Iteracion: 13
# Cantidad de variables: 4 Iteracion: 14
# Cantidad de variables: 4 Iteracion: 17
# Cantidad de variables: 4 Iteracion: 18
# Cantidad de variables: 4 Iteracion: 19
# Cantidad de variables: 4 Iteracion: 20
# Cantidad de variables: 4 Iteracion: 21
# Cantidad de variables: 4 Iteracion: 22
# Cantidad de variables: 4 Iteracion: 23
# Cantidad de variables: 4 Iteracion: 25
# Cantidad de variables: 4 Iteracion: 28
# Cantidad de variables: 4 Iteracion: 30
# Cantidad de variables: 4 Iteracion: 32
# Cantidad de variables: 4 Iteracion: 33
# Cantidad de variables: 4 Iteracion: 34
# Cantidad de variables: 4 Iteracion: 35
# Cantidad de variables: 4 Iteracion: 36
# Cantidad de variables: 4 Iteracion: 37
# Cantidad de variables: 4 Iteracion: 41
# Cantidad de variables: 4 Iteracion: 43
# Cantidad de variables: 4 Iteracion: 45
# Cantidad de variables: 4 Iteracion: 47
# Cantidad de variables: 4 Iteracion: 52
# Cantidad de variables: 4 Iteracion: 53
# Cantidad de variables: 4 Iteracion: 54
# Cantidad de variables: 4 Iteracion: 55
# Cantidad de variables: 4 Iteracion: 57
# Cantidad de variables: 4 Iteracion: 61
# Cantidad de variables: 4 Iteracion: 62
# Cantidad de variables: 4 Iteracion: 63
# Cantidad de variables: 4 Iteracion: 65
# Cantidad de variables: 4 Iteracion: 67
# Cantidad de variables: 4 Iteracion: 68
# Cantidad de variables: 4 Iteracion: 69
# Cantidad de variables: 4 Iteracion: 78
# Cantidad de variables: 4 Iteracion: 82
# Cantidad de variables: 4 Iteracion: 83
# Cantidad de variables: 4 Iteracion: 84
# Cantidad de variables: 4 Iteracion: 85
# Cantidad de variables: 4 Iteracion: 86
# Cantidad de variables: 4 Iteracion: 92
# Cantidad de variables: 4 Iteracion: 93
# Cantidad de variables: 4 Iteracion: 94
# Cantidad de variables: 4 Iteracion: 98
# Cantidad de variables: 5 Iteracion: 1
# Cantidad de variables: 5 Iteracion: 2
# Cantidad de variables: 5 Iteracion: 3
# Cantidad de variables: 5 Iteracion: 4
# Cantidad de variables: 5 Iteracion: 5
# Cantidad de variables: 5 Iteracion: 6
# Cantidad de variables: 5 Iteracion: 7
# Cantidad de variables: 5 Iteracion: 8
# Cantidad de variables: 5 Iteracion: 9
# Cantidad de variables: 5 Iteracion: 10
# Cantidad de variables: 5 Iteracion: 11
# Cantidad de variables: 5 Iteracion: 12
# Cantidad de variables: 5 Iteracion: 13
# Cantidad de variables: 5 Iteracion: 14
# Cantidad de variables: 5 Iteracion: 15
# Cantidad de variables: 5 Iteracion: 16
# Cantidad de variables: 5 Iteracion: 17
# Cantidad de variables: 5 Iteracion: 18
# Cantidad de variables: 5 Iteracion: 19
# Cantidad de variables: 5 Iteracion: 20
# Cantidad de variables: 5 Iteracion: 21
# Cantidad de variables: 5 Iteracion: 22
# Cantidad de variables: 5 Iteracion: 23
# Cantidad de variables: 5 Iteracion: 24
# Cantidad de variables: 5 Iteracion: 25
# Cantidad de variables: 5 Iteracion: 26
# Cantidad de variables: 5 Iteracion: 27
# Cantidad de variables: 5 Iteracion: 28
# Cantidad de variables: 5 Iteracion: 29
# Cantidad de variables: 5 Iteracion: 30
# Cantidad de variables: 5 Iteracion: 31
# Cantidad de variables: 5 Iteracion: 32
# Cantidad de variables: 5 Iteracion: 33
# Cantidad de variables: 5 Iteracion: 34
# Cantidad de variables: 5 Iteracion: 35
# Cantidad de variables: 5 Iteracion: 36
# Cantidad de variables: 5 Iteracion: 37
# Cantidad de variables: 5 Iteracion: 38
# Cantidad de variables: 5 Iteracion: 39
# Cantidad de variables: 5 Iteracion: 40
# Cantidad de variables: 5 Iteracion: 41
# Cantidad de variables: 5 Iteracion: 44
# Cantidad de variables: 5 Iteracion: 45
# Cantidad de variables: 5 Iteracion: 48
# Cantidad de variables: 5 Iteracion: 50
# Cantidad de variables: 5 Iteracion: 52
# Cantidad de variables: 5 Iteracion: 53
# Cantidad de variables: 5 Iteracion: 55
# Cantidad de variables: 5 Iteracion: 56
# Cantidad de variables: 5 Iteracion: 58
# Cantidad de variables: 5 Iteracion: 59
# Cantidad de variables: 5 Iteracion: 60
# Cantidad de variables: 5 Iteracion: 62
# Cantidad de variables: 5 Iteracion: 64
# Cantidad de variables: 5 Iteracion: 65
# Cantidad de variables: 5 Iteracion: 66
# Cantidad de variables: 5 Iteracion: 67
# Cantidad de variables: 5 Iteracion: 68
# Cantidad de variables: 5 Iteracion: 71
# Cantidad de variables: 5 Iteracion: 73
# Cantidad de variables: 5 Iteracion: 75
# Cantidad de variables: 5 Iteracion: 76
# Cantidad de variables: 5 Iteracion: 77
# Cantidad de variables: 5 Iteracion: 78
# Cantidad de variables: 5 Iteracion: 79
# Cantidad de variables: 5 Iteracion: 81
# Cantidad de variables: 5 Iteracion: 82
# Cantidad de variables: 5 Iteracion: 83
# Cantidad de variables: 5 Iteracion: 84
# Cantidad de variables: 5 Iteracion: 86
# Cantidad de variables: 5 Iteracion: 87
# Cantidad de variables: 5 Iteracion: 88
# Cantidad de variables: 5 Iteracion: 89
# Cantidad de variables: 5 Iteracion: 90
# Cantidad de variables: 5 Iteracion: 91
# Cantidad de variables: 5 Iteracion: 98
# Cantidad de variables: 6 Iteracion: 1
# Cantidad de variables: 6 Iteracion: 2
# Cantidad de variables: 6 Iteracion: 3
# Cantidad de variables: 6 Iteracion: 4
# Cantidad de variables: 6 Iteracion: 5
# Cantidad de variables: 6 Iteracion: 7
# Cantidad de variables: 6 Iteracion: 8
# Cantidad de variables: 6 Iteracion: 9
# Cantidad de variables: 6 Iteracion: 10
# Cantidad de variables: 6 Iteracion: 11
# Cantidad de variables: 6 Iteracion: 13
# Cantidad de variables: 6 Iteracion: 14
# Cantidad de variables: 6 Iteracion: 16
# Cantidad de variables: 6 Iteracion: 17
# Cantidad de variables: 6 Iteracion: 18
# Cantidad de variables: 6 Iteracion: 19
# Cantidad de variables: 6 Iteracion: 20
# Cantidad de variables: 6 Iteracion: 21
# Cantidad de variables: 6 Iteracion: 22
# Cantidad de variables: 6 Iteracion: 23
# Cantidad de variables: 6 Iteracion: 24
# Cantidad de variables: 6 Iteracion: 25
# Cantidad de variables: 6 Iteracion: 27
# Cantidad de variables: 6 Iteracion: 28
# Cantidad de variables: 6 Iteracion: 30
# Cantidad de variables: 6 Iteracion: 31
# Cantidad de variables: 6 Iteracion: 32
# Cantidad de variables: 6 Iteracion: 33
# Cantidad de variables: 6 Iteracion: 34
# Cantidad de variables: 6 Iteracion: 35
# Cantidad de variables: 6 Iteracion: 36
# Cantidad de variables: 6 Iteracion: 38
# Cantidad de variables: 6 Iteracion: 39
# Cantidad de variables: 6 Iteracion: 42
# Cantidad de variables: 6 Iteracion: 43
# Cantidad de variables: 6 Iteracion: 45
# Cantidad de variables: 6 Iteracion: 46
# Cantidad de variables: 6 Iteracion: 48
# Cantidad de variables: 6 Iteracion: 49
# Cantidad de variables: 6 Iteracion: 52
# Cantidad de variables: 6 Iteracion: 53
# Cantidad de variables: 6 Iteracion: 55
# Cantidad de variables: 6 Iteracion: 56
# Cantidad de variables: 6 Iteracion: 58
# Cantidad de variables: 6 Iteracion: 60
# Cantidad de variables: 6 Iteracion: 61
# Cantidad de variables: 6 Iteracion: 63
# Cantidad de variables: 6 Iteracion: 64
# Cantidad de variables: 6 Iteracion: 65
# Cantidad de variables: 6 Iteracion: 66
# Cantidad de variables: 6 Iteracion: 67
# Cantidad de variables: 6 Iteracion: 68
# Cantidad de variables: 6 Iteracion: 69
# Cantidad de variables: 6 Iteracion: 70
# Cantidad de variables: 6 Iteracion: 71
# Cantidad de variables: 6 Iteracion: 72
# Cantidad de variables: 6 Iteracion: 73
# Cantidad de variables: 6 Iteracion: 74
# Cantidad de variables: 6 Iteracion: 75
# Cantidad de variables: 6 Iteracion: 76
# Cantidad de variables: 6 Iteracion: 77
# Cantidad de variables: 6 Iteracion: 78
# Cantidad de variables: 6 Iteracion: 80
# Cantidad de variables: 6 Iteracion: 81
# Cantidad de variables: 6 Iteracion: 83
# Cantidad de variables: 6 Iteracion: 84
# Cantidad de variables: 6 Iteracion: 86
# Cantidad de variables: 6 Iteracion: 88
# Cantidad de variables: 6 Iteracion: 89
# Cantidad de variables: 6 Iteracion: 90
# Cantidad de variables: 6 Iteracion: 91
# Cantidad de variables: 6 Iteracion: 92
# Cantidad de variables: 6 Iteracion: 96
# Cantidad de variables: 6 Iteracion: 98
# Cantidad de variables: 7 Iteracion: 1
# Cantidad de variables: 7 Iteracion: 2
# Cantidad de variables: 7 Iteracion: 3
# Cantidad de variables: 7 Iteracion: 4
# Cantidad de variables: 7 Iteracion: 5
# Cantidad de variables: 7 Iteracion: 6
# Cantidad de variables: 7 Iteracion: 7
# Cantidad de variables: 7 Iteracion: 8
# Cantidad de variables: 7 Iteracion: 9
# Cantidad de variables: 7 Iteracion: 10
# Cantidad de variables: 7 Iteracion: 11
# Cantidad de variables: 7 Iteracion: 12
# Cantidad de variables: 7 Iteracion: 13
# Cantidad de variables: 7 Iteracion: 14
# Cantidad de variables: 7 Iteracion: 15
# Cantidad de variables: 7 Iteracion: 16
# Cantidad de variables: 7 Iteracion: 17
# Cantidad de variables: 7 Iteracion: 18
# Cantidad de variables: 7 Iteracion: 19
# Cantidad de variables: 7 Iteracion: 20
# Cantidad de variables: 7 Iteracion: 21
# Cantidad de variables: 7 Iteracion: 22
# Cantidad de variables: 7 Iteracion: 24
# Cantidad de variables: 7 Iteracion: 25
# Cantidad de variables: 7 Iteracion: 26
# Cantidad de variables: 7 Iteracion: 27
# Cantidad de variables: 7 Iteracion: 28
# Cantidad de variables: 7 Iteracion: 29
# Cantidad de variables: 7 Iteracion: 30
# Cantidad de variables: 7 Iteracion: 31
# Cantidad de variables: 7 Iteracion: 32
# Cantidad de variables: 7 Iteracion: 33
# Cantidad de variables: 7 Iteracion: 34
# Cantidad de variables: 7 Iteracion: 35
# Cantidad de variables: 7 Iteracion: 36
# Cantidad de variables: 7 Iteracion: 38
# Cantidad de variables: 7 Iteracion: 40
# Cantidad de variables: 7 Iteracion: 41
# Cantidad de variables: 7 Iteracion: 42
# Cantidad de variables: 7 Iteracion: 44
# Cantidad de variables: 7 Iteracion: 45
# Cantidad de variables: 7 Iteracion: 46
# Cantidad de variables: 7 Iteracion: 47
# Cantidad de variables: 7 Iteracion: 48
# Cantidad de variables: 7 Iteracion: 49
# Cantidad de variables: 7 Iteracion: 50
# Cantidad de variables: 7 Iteracion: 51
# Cantidad de variables: 7 Iteracion: 52
# Cantidad de variables: 7 Iteracion: 53
# Cantidad de variables: 7 Iteracion: 54
# Cantidad de variables: 7 Iteracion: 55
# Cantidad de variables: 7 Iteracion: 56
# Cantidad de variables: 7 Iteracion: 57
# Cantidad de variables: 7 Iteracion: 58
# Cantidad de variables: 7 Iteracion: 59
# Cantidad de variables: 7 Iteracion: 60
# Cantidad de variables: 7 Iteracion: 61
# Cantidad de variables: 7 Iteracion: 63
# Cantidad de variables: 7 Iteracion: 64
# Cantidad de variables: 7 Iteracion: 68
# Cantidad de variables: 7 Iteracion: 69
# Cantidad de variables: 7 Iteracion: 70
# Cantidad de variables: 7 Iteracion: 71
# Cantidad de variables: 7 Iteracion: 72
# Cantidad de variables: 7 Iteracion: 74
# Cantidad de variables: 7 Iteracion: 76
# Cantidad de variables: 7 Iteracion: 77
# Cantidad de variables: 7 Iteracion: 79
# Cantidad de variables: 7 Iteracion: 82
# Cantidad de variables: 7 Iteracion: 83
# Cantidad de variables: 7 Iteracion: 85
# Cantidad de variables: 7 Iteracion: 87
# Cantidad de variables: 7 Iteracion: 88
# Cantidad de variables: 7 Iteracion: 89
# Cantidad de variables: 7 Iteracion: 92
# Cantidad de variables: 7 Iteracion: 93
# Cantidad de variables: 7 Iteracion: 95
# Cantidad de variables: 7 Iteracion: 96
# Cantidad de variables: 7 Iteracion: 97
# Cantidad de variables: 7 Iteracion: 98
# Cantidad de variables: 7 Iteracion: 99
# Cantidad de variables: 8 Iteracion: 1
# Cantidad de variables: 8 Iteracion: 2
# Cantidad de variables: 8 Iteracion: 3
# Cantidad de variables: 8 Iteracion: 4
# Cantidad de variables: 8 Iteracion: 5
# Cantidad de variables: 8 Iteracion: 6
# Cantidad de variables: 8 Iteracion: 7
# Cantidad de variables: 8 Iteracion: 8
# Cantidad de variables: 8 Iteracion: 9
# Cantidad de variables: 8 Iteracion: 10
# Cantidad de variables: 8 Iteracion: 11
# Cantidad de variables: 8 Iteracion: 12
# Cantidad de variables: 8 Iteracion: 13
# Cantidad de variables: 8 Iteracion: 14
# Cantidad de variables: 8 Iteracion: 16
# Cantidad de variables: 8 Iteracion: 17
# Cantidad de variables: 8 Iteracion: 18
# Cantidad de variables: 8 Iteracion: 19
# Cantidad de variables: 8 Iteracion: 20
# Cantidad de variables: 8 Iteracion: 21
# Cantidad de variables: 8 Iteracion: 22
# Cantidad de variables: 8 Iteracion: 23
# Cantidad de variables: 8 Iteracion: 24
# Cantidad de variables: 8 Iteracion: 26
# Cantidad de variables: 8 Iteracion: 27
# Cantidad de variables: 8 Iteracion: 28
# Cantidad de variables: 8 Iteracion: 29
# Cantidad de variables: 8 Iteracion: 30
# Cantidad de variables: 8 Iteracion: 31
# Cantidad de variables: 8 Iteracion: 32
# Cantidad de variables: 8 Iteracion: 33
# Cantidad de variables: 8 Iteracion: 34
# Cantidad de variables: 8 Iteracion: 36
# Cantidad de variables: 8 Iteracion: 37
# Cantidad de variables: 8 Iteracion: 38
# Cantidad de variables: 8 Iteracion: 40
# Cantidad de variables: 8 Iteracion: 41
# Cantidad de variables: 8 Iteracion: 42
# Cantidad de variables: 8 Iteracion: 43
# Cantidad de variables: 8 Iteracion: 44
# Cantidad de variables: 8 Iteracion: 45
# Cantidad de variables: 8 Iteracion: 46
# Cantidad de variables: 8 Iteracion: 47
# Cantidad de variables: 8 Iteracion: 48
# Cantidad de variables: 8 Iteracion: 49
# Cantidad de variables: 8 Iteracion: 51
# Cantidad de variables: 8 Iteracion: 52
# Cantidad de variables: 8 Iteracion: 53
# Cantidad de variables: 8 Iteracion: 54
# Cantidad de variables: 8 Iteracion: 55
# Cantidad de variables: 8 Iteracion: 57
# Cantidad de variables: 8 Iteracion: 58
# Cantidad de variables: 8 Iteracion: 60
# Cantidad de variables: 8 Iteracion: 61
# Cantidad de variables: 8 Iteracion: 63
# Cantidad de variables: 8 Iteracion: 64
# Cantidad de variables: 8 Iteracion: 65
# Cantidad de variables: 8 Iteracion: 66
# Cantidad de variables: 8 Iteracion: 67
# Cantidad de variables: 8 Iteracion: 68
# Cantidad de variables: 8 Iteracion: 69
# Cantidad de variables: 8 Iteracion: 71
# Cantidad de variables: 8 Iteracion: 72
# Cantidad de variables: 8 Iteracion: 74
# Cantidad de variables: 8 Iteracion: 75
# Cantidad de variables: 8 Iteracion: 76
# Cantidad de variables: 8 Iteracion: 77
# Cantidad de variables: 8 Iteracion: 79
# Cantidad de variables: 8 Iteracion: 81
# Cantidad de variables: 8 Iteracion: 82
# Cantidad de variables: 8 Iteracion: 83
# Cantidad de variables: 8 Iteracion: 84
# Cantidad de variables: 8 Iteracion: 85
# Cantidad de variables: 8 Iteracion: 86
# Cantidad de variables: 8 Iteracion: 87
# Cantidad de variables: 8 Iteracion: 89
# Cantidad de variables: 8 Iteracion: 90
# Cantidad de variables: 8 Iteracion: 91
# Cantidad de variables: 8 Iteracion: 92
# Cantidad de variables: 8 Iteracion: 93
# Cantidad de variables: 8 Iteracion: 98
# Cantidad de variables: 9 Iteracion: 1
# Cantidad de variables: 9 Iteracion: 2
# Cantidad de variables: 9 Iteracion: 3
# Cantidad de variables: 9 Iteracion: 4
# Cantidad de variables: 9 Iteracion: 5
# Cantidad de variables: 9 Iteracion: 6
# Cantidad de variables: 9 Iteracion: 7
# Cantidad de variables: 9 Iteracion: 8
# Cantidad de variables: 9 Iteracion: 9
# Cantidad de variables: 9 Iteracion: 10
# Cantidad de variables: 9 Iteracion: 11
# Cantidad de variables: 9 Iteracion: 12
# Cantidad de variables: 9 Iteracion: 13
# Cantidad de variables: 9 Iteracion: 14
# Cantidad de variables: 9 Iteracion: 15
# Cantidad de variables: 9 Iteracion: 16
# Cantidad de variables: 9 Iteracion: 17
# Cantidad de variables: 9 Iteracion: 18
# Cantidad de variables: 9 Iteracion: 19
# Cantidad de variables: 9 Iteracion: 20
# Cantidad de variables: 9 Iteracion: 21
# Cantidad de variables: 9 Iteracion: 22
# Cantidad de variables: 9 Iteracion: 24
# Cantidad de variables: 9 Iteracion: 25
# Cantidad de variables: 9 Iteracion: 26
# Cantidad de variables: 9 Iteracion: 27
# Cantidad de variables: 9 Iteracion: 28
# Cantidad de variables: 9 Iteracion: 29
# Cantidad de variables: 9 Iteracion: 30
# Cantidad de variables: 9 Iteracion: 31
# Cantidad de variables: 9 Iteracion: 32
# Cantidad de variables: 9 Iteracion: 33
# Cantidad de variables: 9 Iteracion: 34
# Cantidad de variables: 9 Iteracion: 35
# Cantidad de variables: 9 Iteracion: 36
# Cantidad de variables: 9 Iteracion: 37
# Cantidad de variables: 9 Iteracion: 38
# Cantidad de variables: 9 Iteracion: 39
# Cantidad de variables: 9 Iteracion: 40
# Cantidad de variables: 9 Iteracion: 42
# Cantidad de variables: 9 Iteracion: 43
# Cantidad de variables: 9 Iteracion: 44
# Cantidad de variables: 9 Iteracion: 45
# Cantidad de variables: 9 Iteracion: 46
# Cantidad de variables: 9 Iteracion: 47
# Cantidad de variables: 9 Iteracion: 48
# Cantidad de variables: 9 Iteracion: 49
# Cantidad de variables: 9 Iteracion: 50
# Cantidad de variables: 9 Iteracion: 51
# Cantidad de variables: 9 Iteracion: 52
# Cantidad de variables: 9 Iteracion: 54
# Cantidad de variables: 9 Iteracion: 55
# Cantidad de variables: 9 Iteracion: 56
# Cantidad de variables: 9 Iteracion: 57
# Cantidad de variables: 9 Iteracion: 58
# Cantidad de variables: 9 Iteracion: 59
# Cantidad de variables: 9 Iteracion: 60
# Cantidad de variables: 9 Iteracion: 61
# Cantidad de variables: 9 Iteracion: 63
# Cantidad de variables: 9 Iteracion: 64
# Cantidad de variables: 9 Iteracion: 65
# Cantidad de variables: 9 Iteracion: 66
# Cantidad de variables: 9 Iteracion: 67
# Cantidad de variables: 9 Iteracion: 68
# Cantidad de variables: 9 Iteracion: 69
# Cantidad de variables: 9 Iteracion: 71
# Cantidad de variables: 9 Iteracion: 72
# Cantidad de variables: 9 Iteracion: 73
# Cantidad de variables: 9 Iteracion: 74
# Cantidad de variables: 9 Iteracion: 75
# Cantidad de variables: 9 Iteracion: 76
# Cantidad de variables: 9 Iteracion: 77
# Cantidad de variables: 9 Iteracion: 79
# Cantidad de variables: 9 Iteracion: 80
# Cantidad de variables: 9 Iteracion: 81
# Cantidad de variables: 9 Iteracion: 83
# Cantidad de variables: 9 Iteracion: 84
# Cantidad de variables: 9 Iteracion: 85
# Cantidad de variables: 9 Iteracion: 86
# Cantidad de variables: 9 Iteracion: 87
# Cantidad de variables: 9 Iteracion: 88
# Cantidad de variables: 9 Iteracion: 89
# Cantidad de variables: 9 Iteracion: 90
# Cantidad de variables: 9 Iteracion: 91
# Cantidad de variables: 9 Iteracion: 93
# Cantidad de variables: 9 Iteracion: 94
# Cantidad de variables: 9 Iteracion: 95
# Cantidad de variables: 9 Iteracion: 96
# Cantidad de variables: 9 Iteracion: 97
# Cantidad de variables: 9 Iteracion: 98
# Cantidad de variables: 9 Iteracion: 99
# Cantidad de variables: 10 Iteracion: 1
# Cantidad de variables: 10 Iteracion: 2
# Cantidad de variables: 10 Iteracion: 3
# Cantidad de variables: 10 Iteracion: 4
# Cantidad de variables: 10 Iteracion: 5
# Cantidad de variables: 10 Iteracion: 6
# Cantidad de variables: 10 Iteracion: 7
# Cantidad de variables: 10 Iteracion: 8
# Cantidad de variables: 10 Iteracion: 9
# Cantidad de variables: 10 Iteracion: 10
# Cantidad de variables: 10 Iteracion: 11
# Cantidad de variables: 10 Iteracion: 12
# Cantidad de variables: 10 Iteracion: 13
# Cantidad de variables: 10 Iteracion: 14
# Cantidad de variables: 10 Iteracion: 15
# Cantidad de variables: 10 Iteracion: 16
# Cantidad de variables: 10 Iteracion: 17
# Cantidad de variables: 10 Iteracion: 18
# Cantidad de variables: 10 Iteracion: 19
# Cantidad de variables: 10 Iteracion: 20
# Cantidad de variables: 10 Iteracion: 21
# Cantidad de variables: 10 Iteracion: 22
# Cantidad de variables: 10 Iteracion: 23
# Cantidad de variables: 10 Iteracion: 24
# Cantidad de variables: 10 Iteracion: 25
# Cantidad de variables: 10 Iteracion: 26
# Cantidad de variables: 10 Iteracion: 27
# Cantidad de variables: 10 Iteracion: 28
# Cantidad de variables: 10 Iteracion: 29
# Cantidad de variables: 10 Iteracion: 31
# Cantidad de variables: 10 Iteracion: 32
# Cantidad de variables: 10 Iteracion: 33
# Cantidad de variables: 10 Iteracion: 35
# Cantidad de variables: 10 Iteracion: 36
# Cantidad de variables: 10 Iteracion: 37
# Cantidad de variables: 10 Iteracion: 38
# Cantidad de variables: 10 Iteracion: 39
# Cantidad de variables: 10 Iteracion: 40
# Cantidad de variables: 10 Iteracion: 41
# Cantidad de variables: 10 Iteracion: 42
# Cantidad de variables: 10 Iteracion: 43
# Cantidad de variables: 10 Iteracion: 44
# Cantidad de variables: 10 Iteracion: 45
# Cantidad de variables: 10 Iteracion: 47
# Cantidad de variables: 10 Iteracion: 48
# Cantidad de variables: 10 Iteracion: 49
# Cantidad de variables: 10 Iteracion: 50
# Cantidad de variables: 10 Iteracion: 51
# Cantidad de variables: 10 Iteracion: 52
# Cantidad de variables: 10 Iteracion: 53
# Cantidad de variables: 10 Iteracion: 55
# Cantidad de variables: 10 Iteracion: 56
# Cantidad de variables: 10 Iteracion: 57
# Cantidad de variables: 10 Iteracion: 58
# Cantidad de variables: 10 Iteracion: 59
# Cantidad de variables: 10 Iteracion: 60
# Cantidad de variables: 10 Iteracion: 61
# Cantidad de variables: 10 Iteracion: 62
# Cantidad de variables: 10 Iteracion: 63
# Cantidad de variables: 10 Iteracion: 64
# Cantidad de variables: 10 Iteracion: 65
# Cantidad de variables: 10 Iteracion: 66
# Cantidad de variables: 10 Iteracion: 67
# Cantidad de variables: 10 Iteracion: 68
# Cantidad de variables: 10 Iteracion: 69
# Cantidad de variables: 10 Iteracion: 70
# Cantidad de variables: 10 Iteracion: 71
# Cantidad de variables: 10 Iteracion: 72
# Cantidad de variables: 10 Iteracion: 73
# Cantidad de variables: 10 Iteracion: 74
# Cantidad de variables: 10 Iteracion: 75
# Cantidad de variables: 10 Iteracion: 77
# Cantidad de variables: 10 Iteracion: 78
# Cantidad de variables: 10 Iteracion: 79
# Cantidad de variables: 10 Iteracion: 80
# Cantidad de variables: 10 Iteracion: 81
# Cantidad de variables: 10 Iteracion: 82
# Cantidad de variables: 10 Iteracion: 83
# Cantidad de variables: 10 Iteracion: 84
# Cantidad de variables: 10 Iteracion: 85
# Cantidad de variables: 10 Iteracion: 86
# Cantidad de variables: 10 Iteracion: 87
# Cantidad de variables: 10 Iteracion: 88
# Cantidad de variables: 10 Iteracion: 89
# Cantidad de variables: 10 Iteracion: 90
# Cantidad de variables: 10 Iteracion: 91
# Cantidad de variables: 10 Iteracion: 92
# Cantidad de variables: 10 Iteracion: 93
# Cantidad de variables: 10 Iteracion: 94
# Cantidad de variables: 10 Iteracion: 95
# Cantidad de variables: 10 Iteracion: 96
# Cantidad de variables: 10 Iteracion: 97
# Cantidad de variables: 10 Iteracion: 98
# Cantidad de variables: 10 Iteracion: 99
# Cantidad de variables: 11 Iteracion: 1
# Cantidad de variables: 11 Iteracion: 2
# Cantidad de variables: 11 Iteracion: 3
# Cantidad de variables: 11 Iteracion: 4
# Cantidad de variables: 11 Iteracion: 5
# Cantidad de variables: 11 Iteracion: 6
# Cantidad de variables: 11 Iteracion: 7
# Cantidad de variables: 11 Iteracion: 8
# Cantidad de variables: 11 Iteracion: 9
# Cantidad de variables: 11 Iteracion: 10
# Cantidad de variables: 11 Iteracion: 11
# Cantidad de variables: 11 Iteracion: 12
# Cantidad de variables: 11 Iteracion: 13
# Cantidad de variables: 11 Iteracion: 14
# Cantidad de variables: 11 Iteracion: 15
# Cantidad de variables: 11 Iteracion: 16
# Cantidad de variables: 11 Iteracion: 17
# Cantidad de variables: 11 Iteracion: 18
# Cantidad de variables: 11 Iteracion: 19
# Cantidad de variables: 11 Iteracion: 20
# Cantidad de variables: 11 Iteracion: 21
# Cantidad de variables: 11 Iteracion: 22
# Cantidad de variables: 11 Iteracion: 23
# Cantidad de variables: 11 Iteracion: 24
# Cantidad de variables: 11 Iteracion: 25
# Cantidad de variables: 11 Iteracion: 26
# Cantidad de variables: 11 Iteracion: 27
# Cantidad de variables: 11 Iteracion: 28
# Cantidad de variables: 11 Iteracion: 29
# Cantidad de variables: 11 Iteracion: 30
# Cantidad de variables: 11 Iteracion: 31
# Cantidad de variables: 11 Iteracion: 32
# Cantidad de variables: 11 Iteracion: 33
# Cantidad de variables: 11 Iteracion: 34
# Cantidad de variables: 11 Iteracion: 35
# Cantidad de variables: 11 Iteracion: 36
# Cantidad de variables: 11 Iteracion: 37
# Cantidad de variables: 11 Iteracion: 38
# Cantidad de variables: 11 Iteracion: 40
# Cantidad de variables: 11 Iteracion: 41
# Cantidad de variables: 11 Iteracion: 42
# Cantidad de variables: 11 Iteracion: 43
# Cantidad de variables: 11 Iteracion: 44
# Cantidad de variables: 11 Iteracion: 45
# Cantidad de variables: 11 Iteracion: 46
# Cantidad de variables: 11 Iteracion: 47
# Cantidad de variables: 11 Iteracion: 48
# Cantidad de variables: 11 Iteracion: 49
# Cantidad de variables: 11 Iteracion: 50
# Cantidad de variables: 11 Iteracion: 51
# Cantidad de variables: 11 Iteracion: 52
# Cantidad de variables: 11 Iteracion: 53
# Cantidad de variables: 11 Iteracion: 55
# Cantidad de variables: 11 Iteracion: 56
# Cantidad de variables: 11 Iteracion: 57
# Cantidad de variables: 11 Iteracion: 58
# Cantidad de variables: 11 Iteracion: 59
# Cantidad de variables: 11 Iteracion: 60
# Cantidad de variables: 11 Iteracion: 61
# Cantidad de variables: 11 Iteracion: 62
# Cantidad de variables: 11 Iteracion: 63
# Cantidad de variables: 11 Iteracion: 65
# Cantidad de variables: 11 Iteracion: 66
# Cantidad de variables: 11 Iteracion: 67
# Cantidad de variables: 11 Iteracion: 68
# Cantidad de variables: 11 Iteracion: 69
# Cantidad de variables: 11 Iteracion: 70
# Cantidad de variables: 11 Iteracion: 71
# Cantidad de variables: 11 Iteracion: 72
# Cantidad de variables: 11 Iteracion: 73
# Cantidad de variables: 11 Iteracion: 74
# Cantidad de variables: 11 Iteracion: 75
# Cantidad de variables: 11 Iteracion: 76
# Cantidad de variables: 11 Iteracion: 77
# Cantidad de variables: 11 Iteracion: 78
# Cantidad de variables: 11 Iteracion: 79
# Cantidad de variables: 11 Iteracion: 80
# Cantidad de variables: 11 Iteracion: 81
# Cantidad de variables: 11 Iteracion: 82
# Cantidad de variables: 11 Iteracion: 83
# Cantidad de variables: 11 Iteracion: 84
# Cantidad de variables: 11 Iteracion: 85
# Cantidad de variables: 11 Iteracion: 86
# Cantidad de variables: 11 Iteracion: 88
# Cantidad de variables: 11 Iteracion: 89
# Cantidad de variables: 11 Iteracion: 91
# Cantidad de variables: 11 Iteracion: 92
# Cantidad de variables: 11 Iteracion: 93
# Cantidad de variables: 11 Iteracion: 94
# Cantidad de variables: 11 Iteracion: 96
# Cantidad de variables: 11 Iteracion: 97
# Cantidad de variables: 11 Iteracion: 98
# Cantidad de variables: 11 Iteracion: 99
# Cantidad de variables: 12 Iteracion: 1
# Cantidad de variables: 12 Iteracion: 2
# Cantidad de variables: 12 Iteracion: 3
# Cantidad de variables: 12 Iteracion: 4
# Cantidad de variables: 12 Iteracion: 5
# Cantidad de variables: 12 Iteracion: 6
# Cantidad de variables: 12 Iteracion: 7
# Cantidad de variables: 12 Iteracion: 8
# Cantidad de variables: 12 Iteracion: 9
# Cantidad de variables: 12 Iteracion: 10
# Cantidad de variables: 12 Iteracion: 11
# Cantidad de variables: 12 Iteracion: 12
# Cantidad de variables: 12 Iteracion: 13
# Cantidad de variables: 12 Iteracion: 14
# Cantidad de variables: 12 Iteracion: 15
# Cantidad de variables: 12 Iteracion: 16
# Cantidad de variables: 12 Iteracion: 17
# Cantidad de variables: 12 Iteracion: 18
# Cantidad de variables: 12 Iteracion: 19
# Cantidad de variables: 12 Iteracion: 20
# Cantidad de variables: 12 Iteracion: 21
# Cantidad de variables: 12 Iteracion: 22
# Cantidad de variables: 12 Iteracion: 23
# Cantidad de variables: 12 Iteracion: 24
# Cantidad de variables: 12 Iteracion: 25
# Cantidad de variables: 12 Iteracion: 26
# Cantidad de variables: 12 Iteracion: 27
# Cantidad de variables: 12 Iteracion: 28
# Cantidad de variables: 12 Iteracion: 29
# Cantidad de variables: 12 Iteracion: 30
# Cantidad de variables: 12 Iteracion: 31
# Cantidad de variables: 12 Iteracion: 32
# Cantidad de variables: 12 Iteracion: 33
# Cantidad de variables: 12 Iteracion: 34
# Cantidad de variables: 12 Iteracion: 35
# Cantidad de variables: 12 Iteracion: 36
# Cantidad de variables: 12 Iteracion: 37
# Cantidad de variables: 12 Iteracion: 38
# Cantidad de variables: 12 Iteracion: 39
# Cantidad de variables: 12 Iteracion: 40
# Cantidad de variables: 12 Iteracion: 41
# Cantidad de variables: 12 Iteracion: 42
# Cantidad de variables: 12 Iteracion: 43
# Cantidad de variables: 12 Iteracion: 44
# Cantidad de variables: 12 Iteracion: 45
# Cantidad de variables: 12 Iteracion: 46
# Cantidad de variables: 12 Iteracion: 47
# Cantidad de variables: 12 Iteracion: 48
# Cantidad de variables: 12 Iteracion: 49
# Cantidad de variables: 12 Iteracion: 50
# Cantidad de variables: 12 Iteracion: 51
# Cantidad de variables: 12 Iteracion: 52
# Cantidad de variables: 12 Iteracion: 53
# Cantidad de variables: 12 Iteracion: 54
# Cantidad de variables: 12 Iteracion: 55
# Cantidad de variables: 12 Iteracion: 56
# Cantidad de variables: 12 Iteracion: 57
# Cantidad de variables: 12 Iteracion: 58
# Cantidad de variables: 12 Iteracion: 59
# Cantidad de variables: 12 Iteracion: 60
# Cantidad de variables: 12 Iteracion: 61
# Cantidad de variables: 12 Iteracion: 62
# Cantidad de variables: 12 Iteracion: 64
# Cantidad de variables: 12 Iteracion: 65
# Cantidad de variables: 12 Iteracion: 66
# Cantidad de variables: 12 Iteracion: 67
# Cantidad de variables: 12 Iteracion: 68
# Cantidad de variables: 12 Iteracion: 69
# Cantidad de variables: 12 Iteracion: 70
# Cantidad de variables: 12 Iteracion: 71
# Cantidad de variables: 12 Iteracion: 72
# Cantidad de variables: 12 Iteracion: 74
# Cantidad de variables: 12 Iteracion: 75
# Cantidad de variables: 12 Iteracion: 76
# Cantidad de variables: 12 Iteracion: 77
# Cantidad de variables: 12 Iteracion: 78
# Cantidad de variables: 12 Iteracion: 79
# Cantidad de variables: 12 Iteracion: 80
# Cantidad de variables: 12 Iteracion: 81
# Cantidad de variables: 12 Iteracion: 82
# Cantidad de variables: 12 Iteracion: 83
# Cantidad de variables: 12 Iteracion: 84
# Cantidad de variables: 12 Iteracion: 85
# Cantidad de variables: 12 Iteracion: 86
# Cantidad de variables: 12 Iteracion: 87
# Cantidad de variables: 12 Iteracion: 88
# Cantidad de variables: 12 Iteracion: 89
# Cantidad de variables: 12 Iteracion: 90
# Cantidad de variables: 12 Iteracion: 91
# Cantidad de variables: 12 Iteracion: 92
# Cantidad de variables: 12 Iteracion: 93
# Cantidad de variables: 12 Iteracion: 94
# Cantidad de variables: 12 Iteracion: 95
# Cantidad de variables: 12 Iteracion: 96
# Cantidad de variables: 12 Iteracion: 97
# Cantidad de variables: 12 Iteracion: 98
# Cantidad de variables: 12 Iteracion: 99
# Cantidad de variables: 13 Iteracion: 1
# Cantidad de variables: 13 Iteracion: 2
# Cantidad de variables: 13 Iteracion: 3
# Cantidad de variables: 13 Iteracion: 4
# Cantidad de variables: 13 Iteracion: 5
# Cantidad de variables: 13 Iteracion: 6
# Cantidad de variables: 13 Iteracion: 7
# Cantidad de variables: 13 Iteracion: 8
# Cantidad de variables: 13 Iteracion: 9
# Cantidad de variables: 13 Iteracion: 10
# Cantidad de variables: 13 Iteracion: 11
# Cantidad de variables: 13 Iteracion: 12
# Cantidad de variables: 13 Iteracion: 13
# Cantidad de variables: 13 Iteracion: 14
# Cantidad de variables: 13 Iteracion: 15
# Cantidad de variables: 13 Iteracion: 16
# Cantidad de variables: 13 Iteracion: 17
# Cantidad de variables: 13 Iteracion: 18
# Cantidad de variables: 13 Iteracion: 19
# Cantidad de variables: 13 Iteracion: 20
# Cantidad de variables: 13 Iteracion: 21
# Cantidad de variables: 13 Iteracion: 22
# Cantidad de variables: 13 Iteracion: 23
# Cantidad de variables: 13 Iteracion: 24
# Cantidad de variables: 13 Iteracion: 25
# Cantidad de variables: 13 Iteracion: 26
# Cantidad de variables: 13 Iteracion: 27
# Cantidad de variables: 13 Iteracion: 28
# Cantidad de variables: 13 Iteracion: 29
# Cantidad de variables: 13 Iteracion: 30
# Cantidad de variables: 13 Iteracion: 32
# Cantidad de variables: 13 Iteracion: 33
# Cantidad de variables: 13 Iteracion: 34
# Cantidad de variables: 13 Iteracion: 35
# Cantidad de variables: 13 Iteracion: 36
# Cantidad de variables: 13 Iteracion: 37
# Cantidad de variables: 13 Iteracion: 38
# Cantidad de variables: 13 Iteracion: 39
# Cantidad de variables: 13 Iteracion: 40
# Cantidad de variables: 13 Iteracion: 41
# Cantidad de variables: 13 Iteracion: 42
# Cantidad de variables: 13 Iteracion: 43
# Cantidad de variables: 13 Iteracion: 44
# Cantidad de variables: 13 Iteracion: 45
# Cantidad de variables: 13 Iteracion: 46
# Cantidad de variables: 13 Iteracion: 47
# Cantidad de variables: 13 Iteracion: 48
# Cantidad de variables: 13 Iteracion: 49
# Cantidad de variables: 13 Iteracion: 50
# Cantidad de variables: 13 Iteracion: 51
# Cantidad de variables: 13 Iteracion: 52
# Cantidad de variables: 13 Iteracion: 53
# Cantidad de variables: 13 Iteracion: 54
# Cantidad de variables: 13 Iteracion: 55
# Cantidad de variables: 13 Iteracion: 56
# Cantidad de variables: 13 Iteracion: 57
# Cantidad de variables: 13 Iteracion: 58
# Cantidad de variables: 13 Iteracion: 59
# Cantidad de variables: 13 Iteracion: 60
# Cantidad de variables: 13 Iteracion: 61
# Cantidad de variables: 13 Iteracion: 62
# Cantidad de variables: 13 Iteracion: 63
# Cantidad de variables: 13 Iteracion: 64
# Cantidad de variables: 13 Iteracion: 65
# Cantidad de variables: 13 Iteracion: 66
# Cantidad de variables: 13 Iteracion: 67
# Cantidad de variables: 13 Iteracion: 68
# Cantidad de variables: 13 Iteracion: 69
# Cantidad de variables: 13 Iteracion: 70
# Cantidad de variables: 13 Iteracion: 71
# Cantidad de variables: 13 Iteracion: 72
# Cantidad de variables: 13 Iteracion: 73
# Cantidad de variables: 13 Iteracion: 74
# Cantidad de variables: 13 Iteracion: 75
# Cantidad de variables: 13 Iteracion: 76
# Cantidad de variables: 13 Iteracion: 77
# Cantidad de variables: 13 Iteracion: 78
# Cantidad de variables: 13 Iteracion: 79
# Cantidad de variables: 13 Iteracion: 80
# Cantidad de variables: 13 Iteracion: 81
# Cantidad de variables: 13 Iteracion: 82
# Cantidad de variables: 13 Iteracion: 83
# Cantidad de variables: 13 Iteracion: 84
# Cantidad de variables: 13 Iteracion: 85
# Cantidad de variables: 13 Iteracion: 86
# Cantidad de variables: 13 Iteracion: 87
# Cantidad de variables: 13 Iteracion: 88
# Cantidad de variables: 13 Iteracion: 90
# Cantidad de variables: 13 Iteracion: 91
# Cantidad de variables: 13 Iteracion: 92
# Cantidad de variables: 13 Iteracion: 93
# Cantidad de variables: 13 Iteracion: 94
# Cantidad de variables: 13 Iteracion: 95
# Cantidad de variables: 13 Iteracion: 96
# Cantidad de variables: 13 Iteracion: 97
# Cantidad de variables: 13 Iteracion: 98
# Cantidad de variables: 13 Iteracion: 99
# Cantidad de variables: 14 Iteracion: 1
# Cantidad de variables: 14 Iteracion: 2
# Cantidad de variables: 14 Iteracion: 3
# Cantidad de variables: 14 Iteracion: 4
# Cantidad de variables: 14 Iteracion: 5
# Cantidad de variables: 14 Iteracion: 6
# Cantidad de variables: 14 Iteracion: 7
# Cantidad de variables: 14 Iteracion: 8
# Cantidad de variables: 14 Iteracion: 9
# Cantidad de variables: 14 Iteracion: 10
# Cantidad de variables: 14 Iteracion: 11
# Cantidad de variables: 14 Iteracion: 12
# Cantidad de variables: 14 Iteracion: 13
# Cantidad de variables: 14 Iteracion: 14
# Cantidad de variables: 14 Iteracion: 15
# Cantidad de variables: 14 Iteracion: 16
# Cantidad de variables: 14 Iteracion: 17
# Cantidad de variables: 14 Iteracion: 18
# Cantidad de variables: 14 Iteracion: 19
# Cantidad de variables: 14 Iteracion: 20
# Cantidad de variables: 14 Iteracion: 21
# Cantidad de variables: 14 Iteracion: 22
# Cantidad de variables: 14 Iteracion: 23
# Cantidad de variables: 14 Iteracion: 24
# Cantidad de variables: 14 Iteracion: 25
# Cantidad de variables: 14 Iteracion: 26
# Cantidad de variables: 14 Iteracion: 27
# Cantidad de variables: 14 Iteracion: 28
# Cantidad de variables: 14 Iteracion: 29
# Cantidad de variables: 14 Iteracion: 30
# Cantidad de variables: 14 Iteracion: 31
# Cantidad de variables: 14 Iteracion: 32
# Cantidad de variables: 14 Iteracion: 33
# Cantidad de variables: 14 Iteracion: 34
# Cantidad de variables: 14 Iteracion: 35
# Cantidad de variables: 14 Iteracion: 36
# Cantidad de variables: 14 Iteracion: 37
# Cantidad de variables: 14 Iteracion: 38
# Cantidad de variables: 14 Iteracion: 39
# Cantidad de variables: 14 Iteracion: 40
# Cantidad de variables: 14 Iteracion: 41
# Cantidad de variables: 14 Iteracion: 42
# Cantidad de variables: 14 Iteracion: 43
# Cantidad de variables: 14 Iteracion: 44
# Cantidad de variables: 14 Iteracion: 45
# Cantidad de variables: 14 Iteracion: 46
# Cantidad de variables: 14 Iteracion: 47
# Cantidad de variables: 14 Iteracion: 48
# Cantidad de variables: 14 Iteracion: 49
# Cantidad de variables: 14 Iteracion: 50
# Cantidad de variables: 14 Iteracion: 51
# Cantidad de variables: 14 Iteracion: 52
# Cantidad de variables: 14 Iteracion: 53
# Cantidad de variables: 14 Iteracion: 54
# Cantidad de variables: 14 Iteracion: 55
# Cantidad de variables: 14 Iteracion: 56
# Cantidad de variables: 14 Iteracion: 57
# Cantidad de variables: 14 Iteracion: 58
# Cantidad de variables: 14 Iteracion: 59
# Cantidad de variables: 14 Iteracion: 60
# Cantidad de variables: 14 Iteracion: 61
# Cantidad de variables: 14 Iteracion: 62
# Cantidad de variables: 14 Iteracion: 63
# Cantidad de variables: 14 Iteracion: 64
# Cantidad de variables: 14 Iteracion: 65
# Cantidad de variables: 14 Iteracion: 66
# Cantidad de variables: 14 Iteracion: 67
# Cantidad de variables: 14 Iteracion: 68
# Cantidad de variables: 14 Iteracion: 69
# Cantidad de variables: 14 Iteracion: 70
# Cantidad de variables: 14 Iteracion: 71
# Cantidad de variables: 14 Iteracion: 72
# Cantidad de variables: 14 Iteracion: 73
# Cantidad de variables: 14 Iteracion: 74
# Cantidad de variables: 14 Iteracion: 75
# Cantidad de variables: 14 Iteracion: 76
# Cantidad de variables: 14 Iteracion: 77
# Cantidad de variables: 14 Iteracion: 78
# Cantidad de variables: 14 Iteracion: 79
# Cantidad de variables: 14 Iteracion: 80
# Cantidad de variables: 14 Iteracion: 81
# Cantidad de variables: 14 Iteracion: 82
# Cantidad de variables: 14 Iteracion: 83
# Cantidad de variables: 14 Iteracion: 84
# Cantidad de variables: 14 Iteracion: 85
# Cantidad de variables: 14 Iteracion: 86
# Cantidad de variables: 14 Iteracion: 87
# Cantidad de variables: 14 Iteracion: 88
# Cantidad de variables: 14 Iteracion: 89
# Cantidad de variables: 14 Iteracion: 90
# Cantidad de variables: 14 Iteracion: 91
# Cantidad de variables: 14 Iteracion: 92
# Cantidad de variables: 14 Iteracion: 93
# Cantidad de variables: 14 Iteracion: 94
# Cantidad de variables: 14 Iteracion: 95
# Cantidad de variables: 14 Iteracion: 96
# Cantidad de variables: 14 Iteracion: 97
# Cantidad de variables: 14 Iteracion: 98
# Cantidad de variables: 14 Iteracion: 99
# Lasso alpha: 0.1 Iteracion: 1
# Lasso alpha: 0.1 Iteracion: 2
# Lasso alpha: 0.1 Iteracion: 3
# Lasso alpha: 0.1 Iteracion: 4
# Lasso alpha: 0.1 Iteracion: 5
# Lasso alpha: 0.1 Iteracion: 6
# Lasso alpha: 0.1 Iteracion: 7
# Lasso alpha: 0.1 Iteracion: 8
# Lasso alpha: 0.1 Iteracion: 9
# Lasso alpha: 0.1 Iteracion: 10
# Lasso alpha: 0.1 Iteracion: 11
# Lasso alpha: 0.1 Iteracion: 12
# Lasso alpha: 0.1 Iteracion: 13
# Lasso alpha: 0.1 Iteracion: 14
# Lasso alpha: 0.1 Iteracion: 15
# Lasso alpha: 0.1 Iteracion: 16
# Lasso alpha: 0.1 Iteracion: 17
# Lasso alpha: 0.1 Iteracion: 18
# Lasso alpha: 0.1 Iteracion: 19
# Lasso alpha: 0.1 Iteracion: 20
# Lasso alpha: 0.1 Iteracion: 21
# Lasso alpha: 0.1 Iteracion: 22
# Lasso alpha: 0.1 Iteracion: 23
# Lasso alpha: 0.1 Iteracion: 24
# Lasso alpha: 0.1 Iteracion: 25
# Lasso alpha: 0.1 Iteracion: 26
# Lasso alpha: 0.1 Iteracion: 27
# Lasso alpha: 0.1 Iteracion: 28
# Lasso alpha: 0.1 Iteracion: 29
# Lasso alpha: 0.1 Iteracion: 30
# Lasso alpha: 0.1 Iteracion: 31
# Lasso alpha: 0.1 Iteracion: 32
# Lasso alpha: 0.1 Iteracion: 33
# Lasso alpha: 0.1 Iteracion: 34
# Lasso alpha: 0.1 Iteracion: 35
# Lasso alpha: 0.1 Iteracion: 36
# Lasso alpha: 0.1 Iteracion: 37
# Lasso alpha: 0.1 Iteracion: 38
# Lasso alpha: 0.1 Iteracion: 40
# Lasso alpha: 0.1 Iteracion: 41
# Lasso alpha: 0.1 Iteracion: 42
# Lasso alpha: 0.1 Iteracion: 43
# Lasso alpha: 0.1 Iteracion: 44
# Lasso alpha: 0.1 Iteracion: 45
# Lasso alpha: 0.1 Iteracion: 46
# Lasso alpha: 0.1 Iteracion: 47
# Lasso alpha: 0.1 Iteracion: 48
# Lasso alpha: 0.1 Iteracion: 49
# Lasso alpha: 0.1 Iteracion: 50
# Lasso alpha: 0.1 Iteracion: 51
# Lasso alpha: 0.1 Iteracion: 52
# Lasso alpha: 0.1 Iteracion: 53
# Lasso alpha: 0.1 Iteracion: 54
# Lasso alpha: 0.1 Iteracion: 55
# Lasso alpha: 0.1 Iteracion: 56
# Lasso alpha: 0.1 Iteracion: 57
# Lasso alpha: 0.1 Iteracion: 58
# Lasso alpha: 0.1 Iteracion: 59
# Lasso alpha: 0.1 Iteracion: 60
# Lasso alpha: 0.1 Iteracion: 61
# Lasso alpha: 0.1 Iteracion: 62
# Lasso alpha: 0.1 Iteracion: 63
# Lasso alpha: 0.1 Iteracion: 64
# Lasso alpha: 0.1 Iteracion: 65
# Lasso alpha: 0.1 Iteracion: 66
# Lasso alpha: 0.1 Iteracion: 67
# Lasso alpha: 0.1 Iteracion: 68
# Lasso alpha: 0.1 Iteracion: 69
# Lasso alpha: 0.1 Iteracion: 70
# Lasso alpha: 0.1 Iteracion: 71
# Lasso alpha: 0.1 Iteracion: 72
# Lasso alpha: 0.1 Iteracion: 73
# Lasso alpha: 0.1 Iteracion: 74
# Lasso alpha: 0.1 Iteracion: 75
# Lasso alpha: 0.1 Iteracion: 76
# Lasso alpha: 0.1 Iteracion: 77
# Lasso alpha: 0.1 Iteracion: 78
# Lasso alpha: 0.1 Iteracion: 79
# Lasso alpha: 0.1 Iteracion: 80
# Lasso alpha: 0.1 Iteracion: 81
# Lasso alpha: 0.1 Iteracion: 82
# Lasso alpha: 0.1 Iteracion: 83
# Lasso alpha: 0.1 Iteracion: 84
# Lasso alpha: 0.1 Iteracion: 85
# Lasso alpha: 0.1 Iteracion: 86
# Lasso alpha: 0.1 Iteracion: 87
# Lasso alpha: 0.1 Iteracion: 88
# Lasso alpha: 0.1 Iteracion: 89
# Lasso alpha: 0.1 Iteracion: 90
# Lasso alpha: 0.1 Iteracion: 91
# Lasso alpha: 0.1 Iteracion: 92
# Lasso alpha: 0.1 Iteracion: 93
# Lasso alpha: 0.1 Iteracion: 94
# Lasso alpha: 0.1 Iteracion: 95
# Lasso alpha: 0.1 Iteracion: 96
# Lasso alpha: 0.1 Iteracion: 97
# Lasso alpha: 0.1 Iteracion: 98
# Lasso alpha: 0.1 Iteracion: 99
# Lasso alpha: 0.2 Iteracion: 1
# Lasso alpha: 0.2 Iteracion: 2
# Lasso alpha: 0.2 Iteracion: 3
# Lasso alpha: 0.2 Iteracion: 4
# Lasso alpha: 0.2 Iteracion: 5
# Lasso alpha: 0.2 Iteracion: 6
# Lasso alpha: 0.2 Iteracion: 7
# Lasso alpha: 0.2 Iteracion: 8
# Lasso alpha: 0.2 Iteracion: 9
# Lasso alpha: 0.2 Iteracion: 10
# Lasso alpha: 0.2 Iteracion: 11
# Lasso alpha: 0.2 Iteracion: 12
# Lasso alpha: 0.2 Iteracion: 13
# Lasso alpha: 0.2 Iteracion: 14
# Lasso alpha: 0.2 Iteracion: 15
# Lasso alpha: 0.2 Iteracion: 16
# Lasso alpha: 0.2 Iteracion: 17
# Lasso alpha: 0.2 Iteracion: 18
# Lasso alpha: 0.2 Iteracion: 19
# Lasso alpha: 0.2 Iteracion: 20
# Lasso alpha: 0.2 Iteracion: 21
# Lasso alpha: 0.2 Iteracion: 22
# Lasso alpha: 0.2 Iteracion: 23
# Lasso alpha: 0.2 Iteracion: 24
# Lasso alpha: 0.2 Iteracion: 25
# Lasso alpha: 0.2 Iteracion: 26
# Lasso alpha: 0.2 Iteracion: 27
# Lasso alpha: 0.2 Iteracion: 28
# Lasso alpha: 0.2 Iteracion: 29
# Lasso alpha: 0.2 Iteracion: 30
# Lasso alpha: 0.2 Iteracion: 31
# Lasso alpha: 0.2 Iteracion: 32
# Lasso alpha: 0.2 Iteracion: 33
# Lasso alpha: 0.2 Iteracion: 34
# Lasso alpha: 0.2 Iteracion: 35
# Lasso alpha: 0.2 Iteracion: 36
# Lasso alpha: 0.2 Iteracion: 37
# Lasso alpha: 0.2 Iteracion: 38
# Lasso alpha: 0.2 Iteracion: 39
# Lasso alpha: 0.2 Iteracion: 40
# Lasso alpha: 0.2 Iteracion: 41
# Lasso alpha: 0.2 Iteracion: 42
# Lasso alpha: 0.2 Iteracion: 44
# Lasso alpha: 0.2 Iteracion: 45
# Lasso alpha: 0.2 Iteracion: 46
# Lasso alpha: 0.2 Iteracion: 47
# Lasso alpha: 0.2 Iteracion: 49
# Lasso alpha: 0.2 Iteracion: 50
# Lasso alpha: 0.2 Iteracion: 51
# Lasso alpha: 0.2 Iteracion: 52
# Lasso alpha: 0.2 Iteracion: 53
# Lasso alpha: 0.2 Iteracion: 54
# Lasso alpha: 0.2 Iteracion: 56
# Lasso alpha: 0.2 Iteracion: 57
# Lasso alpha: 0.2 Iteracion: 58
# Lasso alpha: 0.2 Iteracion: 60
# Lasso alpha: 0.2 Iteracion: 62
# Lasso alpha: 0.2 Iteracion: 63
# Lasso alpha: 0.2 Iteracion: 64
# Lasso alpha: 0.2 Iteracion: 65
# Lasso alpha: 0.2 Iteracion: 66
# Lasso alpha: 0.2 Iteracion: 67
# Lasso alpha: 0.2 Iteracion: 68
# Lasso alpha: 0.2 Iteracion: 70
# Lasso alpha: 0.2 Iteracion: 71
# Lasso alpha: 0.2 Iteracion: 72
# Lasso alpha: 0.2 Iteracion: 73
# Lasso alpha: 0.2 Iteracion: 74
# Lasso alpha: 0.2 Iteracion: 75
# Lasso alpha: 0.2 Iteracion: 77
# Lasso alpha: 0.2 Iteracion: 78
# Lasso alpha: 0.2 Iteracion: 79
# Lasso alpha: 0.2 Iteracion: 80
# Lasso alpha: 0.2 Iteracion: 81
# Lasso alpha: 0.2 Iteracion: 82
# Lasso alpha: 0.2 Iteracion: 83
# Lasso alpha: 0.2 Iteracion: 84
# Lasso alpha: 0.2 Iteracion: 85
# Lasso alpha: 0.2 Iteracion: 86
# Lasso alpha: 0.2 Iteracion: 87
# Lasso alpha: 0.2 Iteracion: 88
# Lasso alpha: 0.2 Iteracion: 90
# Lasso alpha: 0.2 Iteracion: 91
# Lasso alpha: 0.2 Iteracion: 92
# Lasso alpha: 0.2 Iteracion: 93
# Lasso alpha: 0.2 Iteracion: 94
# Lasso alpha: 0.2 Iteracion: 95
# Lasso alpha: 0.2 Iteracion: 96
# Lasso alpha: 0.2 Iteracion: 97
# Lasso alpha: 0.2 Iteracion: 98
# Lasso alpha: 0.2 Iteracion: 99
# Lasso alpha: 0.30000000000000004 Iteracion: 1
# Lasso alpha: 0.30000000000000004 Iteracion: 7
# Lasso alpha: 0.30000000000000004 Iteracion: 8
# Lasso alpha: 0.30000000000000004 Iteracion: 9
# Lasso alpha: 0.30000000000000004 Iteracion: 11
# Lasso alpha: 0.30000000000000004 Iteracion: 12
# Lasso alpha: 0.30000000000000004 Iteracion: 13
# Lasso alpha: 0.30000000000000004 Iteracion: 14
# Lasso alpha: 0.30000000000000004 Iteracion: 15
# Lasso alpha: 0.30000000000000004 Iteracion: 17
# Lasso alpha: 0.30000000000000004 Iteracion: 21
# Lasso alpha: 0.30000000000000004 Iteracion: 24
# Lasso alpha: 0.30000000000000004 Iteracion: 25
# Lasso alpha: 0.30000000000000004 Iteracion: 26
# Lasso alpha: 0.30000000000000004 Iteracion: 27
# Lasso alpha: 0.30000000000000004 Iteracion: 28
# Lasso alpha: 0.30000000000000004 Iteracion: 29
# Lasso alpha: 0.30000000000000004 Iteracion: 34
# Lasso alpha: 0.30000000000000004 Iteracion: 35
# Lasso alpha: 0.30000000000000004 Iteracion: 36
# Lasso alpha: 0.30000000000000004 Iteracion: 40
# Lasso alpha: 0.30000000000000004 Iteracion: 41
# Lasso alpha: 0.30000000000000004 Iteracion: 42
# Lasso alpha: 0.30000000000000004 Iteracion: 43
# Lasso alpha: 0.30000000000000004 Iteracion: 44
# Lasso alpha: 0.30000000000000004 Iteracion: 45
# Lasso alpha: 0.30000000000000004 Iteracion: 48
# Lasso alpha: 0.30000000000000004 Iteracion: 50
# Lasso alpha: 0.30000000000000004 Iteracion: 51
# Lasso alpha: 0.30000000000000004 Iteracion: 52
# Lasso alpha: 0.30000000000000004 Iteracion: 53
# Lasso alpha: 0.30000000000000004 Iteracion: 54
# Lasso alpha: 0.30000000000000004 Iteracion: 55
# Lasso alpha: 0.30000000000000004 Iteracion: 57
# Lasso alpha: 0.30000000000000004 Iteracion: 58
# Lasso alpha: 0.30000000000000004 Iteracion: 59
# Lasso alpha: 0.30000000000000004 Iteracion: 62
# Lasso alpha: 0.30000000000000004 Iteracion: 65
# Lasso alpha: 0.30000000000000004 Iteracion: 66
# Lasso alpha: 0.30000000000000004 Iteracion: 71
# Lasso alpha: 0.30000000000000004 Iteracion: 73
# Lasso alpha: 0.30000000000000004 Iteracion: 76
# Lasso alpha: 0.30000000000000004 Iteracion: 78
# Lasso alpha: 0.30000000000000004 Iteracion: 79
# Lasso alpha: 0.30000000000000004 Iteracion: 80
# Lasso alpha: 0.30000000000000004 Iteracion: 85
# ...
# El conjunto de variables Lasso alpha: 0.5 Iteracion: 14 no tiene variables
# El conjunto de variables Lasso alpha: 0.5 Iteracion: 14 no tiene variables
# El conjunto de variables Lasso alpha: 0.5 Iteracion: 14 no tiene variables
# El conjunto de variables Lasso alpha: 0.5 Iteracion: 14 no tiene variables
# El conjunto de variables Lasso alpha: 0.5 Iteracion: 14 no tiene variables
# El conjunto de variables Lasso alpha: 0.5 Iteracion: 14 no tiene variables
# El conjunto de variables Lasso alpha: 0.5 Iteracion: 14 no tiene variables
# El conjunto de variables Lasso alpha: 0.5 Iteracion: 14 no tiene variables
# El conjunto de variables Lasso alpha: 0.5 Iteracion: 14 no tiene variables
# El conjunto de variables Lasso alpha: 0.5 Iteracion: 14 no tiene variables
# El conjunto de variables Lasso alpha: 0.5 Iteracion: 14 no tiene variables
# El conjunto de variables Lasso alpha: 0.5 Iteracion: 14 no tiene variables
# El conjunto de variables Lasso alpha: 0.5 Iteracion: 14 no tiene variables
# El conjunto de variables Lasso alpha: 0.5 Iteracion: 14 no tiene variables
# El conjunto de variables Lasso alpha: 0.5 Iteracion: 14 no tiene variables
# El conjunto de variables Lasso alpha: 0.5 Iteracion: 14 no tiene variables
# El conjunto de variables Lasso alpha: 0.5 Iteracion: 14 no tiene variables
# El conjunto de variables Lasso alpha: 0.5 Iteracion: 14 no tiene variables
# El conjunto de variables Lasso alpha: 0.5 Iteracion: 14 no tiene variables
# El conjunto de variables Lasso alpha: 0.5 Iteracion: 14 no tiene variables
# El conjunto de variables Lasso alpha: 0.5 Iteracion: 14 no tiene variables
# El conjunto de variables Lasso alpha: 0.5 Iteracion: 14 no tiene variables
# El conjunto de variables Lasso alpha: 0.5 Iteracion: 14 no tiene variables
# El conjunto de variables Lasso alpha: 0.5 Iteracion: 14 no tiene variables
# El conjunto de variables Lasso alpha: 0.5 Iteracion: 14 no tiene variables
# El conjunto de variables Lasso alpha: 0.5 Iteracion: 14 no tiene variables
# El conjunto de variables Lasso alpha: 0.5 Iteracion: 14 no tiene variables
# El conjunto de variables Lasso alpha: 0.5 Iteracion: 14 no tiene variables
# El conjunto de variables Lasso alpha: 0.5 Iteracion: 14 no tiene variables
# El conjunto de variables Lasso alpha: 0.5 Iteracion: 14 no tiene variables
# El conjunto de variables Lasso alpha: 0.5 Iteracion: 14 no tiene variables
# El conjunto de variables Lasso alpha: 0.5 Iteracion: 14 no tiene variables
# El conjunto de variables Lasso alpha: 0.5 Iteracion: 14 no tiene variables
# El conjunto de variables Lasso alpha: 0.5 Iteracion: 14 no tiene variables
# El conjunto de variables Lasso alpha: 0.5 Iteracion: 14 no tiene variables
# El conjunto de variables Lasso alpha: 0.5 Iteracion: 14 no tiene variables
# El conjunto de variables Lasso alpha: 0.5 Iteracion: 14 no tiene variables
# El conjunto de variables Lasso alpha: 0.5 Iteracion: 14 no tiene variables
# El conjunto de variables Lasso alpha: 0.5 Iteracion: 14 no tiene variables
# El conjunto de variables Lasso alpha: 0.5 Iteracion: 14 no tiene variables
# El conjunto de variables Lasso alpha: 0.5 Iteracion: 14 no tiene variables
# El conjunto de variables Lasso alpha: 0.5 Iteracion: 14 no tiene variables
# El conjunto de variables Lasso alpha: 0.5 Iteracion: 14 no tiene variables
# El conjunto de variables Lasso alpha: 0.5 Iteracion: 14 no tiene variables
# El conjunto de variables Lasso alpha: 0.5 Iteracion: 14 no tiene variables
# El conjunto de variables Lasso alpha: 0.5 Iteracion: 14 no tiene variables
# El conjunto de variables Lasso alpha: 0.5 Iteracion: 14 no tiene variables
# El conjunto de variables Lasso alpha: 0.5 Iteracion: 14 no tiene variables
# El conjunto de variables Lasso alpha: 0.5 Iteracion: 14 no tiene variables
# El conjunto de variables Lasso alpha: 0.5 Iteracion: 14 no tiene variables
# El conjunto de variables Lasso alpha: 0.5 Iteracion: 14 no tiene variables
# El conjunto de variables Lasso alpha: 0.5 Iteracion: 14 no tiene variables
# El conjunto de variables Lasso alpha: 0.5 Iteracion: 14 no tiene variables
# El conjunto de variables Lasso alpha: 0.5 Iteracion: 14 no tiene variables
# El conjunto de variables Lasso alpha: 0.5 Iteracion: 14 no tiene variables
# El conjunto de variables Lasso alpha: 0.5 Iteracion: 14 no tiene variables
# El conjunto de variables Lasso alpha: 0.5 Iteracion: 14 no tiene variables
# El conjunto de variables Lasso alpha: 0.5 Iteracion: 14 no tiene variables
# El conjunto de variables Lasso alpha: 0.5 Iteracion: 14 no tiene variables
# El conjunto de variables Lasso alpha: 0.5 Iteracion: 14 no tiene variables
# El conjunto de variables Lasso alpha: 0.5 Iteracion: 14 no tiene variables
# El conjunto de variables Lasso alpha: 0.5 Iteracion: 14 no tiene variables
# El conjunto de variables Lasso alpha: 0.5 Iteracion: 14 no tiene variables
# El conjunto de variables Lasso alpha: 0.5 Iteracion: 14 no tiene variables
# El conjunto de variables Lasso alpha: 0.5 Iteracion: 14 no tiene variables
# El conjunto de variables Lasso alpha: 0.5 Iteracion: 14 no tiene variables
# El conjunto de variables Lasso alpha: 0.5 Iteracion: 14 no tiene variables
# El conjunto de variables Lasso alpha: 0.5 Iteracion: 14 no tiene variables
# El conjunto de variables Lasso alpha: 0.5 Iteracion: 14 no tiene variables
# El conjunto de variables Lasso alpha: 0.5 Iteracion: 14 no tiene variables
# El conjunto de variables Lasso alpha: 0.5 Iteracion: 14 no tiene variables
# El conjunto de variables Lasso alpha: 0.5 Iteracion: 14 no tiene variables
# El conjunto de variables Lasso alpha: 0.5 Iteracion: 14 no tiene variables
# El conjunto de variables Lasso alpha: 0.5 Iteracion: 14 no tiene variables
# El conjunto de variables Lasso alpha: 0.5 Iteracion: 14 no tiene variables
# El conjunto de variables Lasso alpha: 0.5 Iteracion: 14 no tiene variables
# El conjunto de variables Lasso alpha: 0.5 Iteracion: 14 no tiene variables
# El conjunto de variables Lasso alpha: 0.5 Iteracion: 14 no tiene variables
# El conjunto de variables Lasso alpha: 0.5 Iteracion: 14 no tiene variables
# El conjunto de variables Lasso alpha: 0.5 Iteracion: 14 no tiene variables
# El conjunto de variables Lasso alpha: 0.5 Iteracion: 14 no tiene variables
# El conjunto de variables Lasso alpha: 0.5 Iteracion: 14 no tiene variables
# El conjunto de variables Lasso alpha: 0.5 Iteracion: 14 no tiene variables
# El conjunto de variables Lasso alpha: 0.5 Iteracion: 14 no tiene variables
# El conjunto de variables Lasso alpha: 0.5 Iteracion: 14 no tiene variables
# El conjunto de variables Lasso alpha: 0.5 Iteracion: 14 no tiene variables
# El conjunto de variables Lasso alpha: 0.5 Iteracion: 14 no tiene variables
# El conjunto de variables Lasso alpha: 0.5 Iteracion: 14 no tiene variables
# El conjunto de variables Lasso alpha: 0.5 Iteracion: 14 no tiene variables
# El conjunto de variables Lasso alpha: 0.5 Iteracion: 14 no tiene variables
# El conjunto de variables Lasso alpha: 0.5 Iteracion: 14 no tiene variables
# El conjunto de variables Lasso alpha: 0.5 Iteracion: 14 no tiene variables
# El conjunto de variables Lasso alpha: 0.5 Iteracion: 14 no tiene variables
# El conjunto de variables Lasso alpha: 0.5 Iteracion: 14 no tiene variables
# El conjunto de variables Lasso alpha: 0.5 Iteracion: 14 no tiene variables
# El conjunto de variables Lasso alpha: 0.5 Iteracion: 14 no tiene variables
# El conjunto de variables Lasso alpha: 0.5 Iteracion: 14 no tiene variables
# El conjunto de variables Lasso alpha: 0.5 Iteracion: 14 no tiene variables
# El conjunto de variables Lasso alpha: 0.5 Iteracion: 14 no tiene variables
# El conjunto de variables Lasso alpha: 0.5 Iteracion: 14 no tiene variables
# El conjunto de variables Lasso alpha: 0.5 Iteracion: 14 no tiene variables
# El conjunto de variables Lasso alpha: 0.5 Iteracion: 14 no tiene variables
# El conjunto de variables Lasso alpha: 0.5 Iteracion: 14 no tiene variables
# El conjunto de variables Lasso alpha: 0.5 Iteracion: 14 no tiene variables
# El conjunto de variables Lasso alpha: 0.5 Iteracion: 14 no tiene variables
# El conjunto de variables Lasso alpha: 0.5 Iteracion: 14 no tiene variables
# El conjunto de variables Lasso alpha: 0.5 Iteracion: 14 no tiene variables
# El conjunto de variables Lasso alpha: 0.5 Iteracion: 14 no tiene variables
# El conjunto de variables Lasso alpha: 0.5 Iteracion: 14 no tiene variables
# El conjunto de variables Lasso alpha: 0.5 Iteracion: 14 no tiene variables
# El conjunto de variables Lasso alpha: 0.5 Iteracion: 14 no tiene variables
# El conjunto de variables Lasso alpha: 0.5 Iteracion: 14 no tiene variables
# El conjunto de variables Lasso alpha: 0.5 Iteracion: 14 no tiene variables
# El conjunto de variables Lasso alpha: 0.5 Iteracion: 14 no tiene variables
# El conjunto de variables Lasso alpha: 0.5 Iteracion: 14 no tiene variables
# El conjunto de variables Lasso alpha: 0.5 Iteracion: 14 no tiene variables
# El conjunto de variables Lasso alpha: 0.5 Iteracion: 14 no tiene variables
# El conjunto de variables Lasso alpha: 0.5 Iteracion: 14 no tiene variables
# El conjunto de variables Lasso alpha: 0.5 Iteracion: 14 no tiene variables
# El conjunto de variables Lasso alpha: 0.5 Iteracion: 14 no tiene variables
# El conjunto de variables Lasso alpha: 0.5 Iteracion: 14 no tiene variables
# El conjunto de variables Lasso alpha: 0.5 Iteracion: 14 no tiene variables
# El conjunto de variables Lasso alpha: 0.5 Iteracion: 14 no tiene variables
# El conjunto de variables Lasso alpha: 0.5 Iteracion: 14 no tiene variables
# El conjunto de variables Lasso alpha: 0.5 Iteracion: 14 no tiene variables
# El conjunto de variables Lasso alpha: 0.5 Iteracion: 14 no tiene variables
# El conjunto de variables Lasso alpha: 0.5 Iteracion: 14 no tiene variables
# El conjunto de variables Lasso alpha: 0.5 Iteracion: 14 no tiene variables
# El conjunto de variables Lasso alpha: 0.5 Iteracion: 14 no tiene variables
# El conjunto de variables Lasso alpha: 0.5 Iteracion: 14 no tiene variables
# El conjunto de variables Lasso alpha: 0.5 Iteracion: 14 no tiene variables
# El conjunto de variables Lasso alpha: 0.5 Iteracion: 14 no tiene variables
# El conjunto de variables Lasso alpha: 0.5 Iteracion: 14 no tiene variables
# El conjunto de variables Lasso alpha: 0.5 Iteracion: 14 no tiene variables
# El conjunto de variables Lasso alpha: 0.5 Iteracion: 14 no tiene variables
# El conjunto de variables Lasso alpha: 0.5 Iteracion: 14 no tiene variables
# El conjunto de variables Lasso alpha: 0.5 Iteracion: 14 no tiene variables
# El conjunto de variables Lasso alpha: 0.5 Iteracion: 14 no tiene variables
# El conjunto de variables Lasso alpha: 0.5 Iteracion: 14 no tiene variables
# El conjunto de variables Lasso alpha: 0.5 Iteracion: 14 no tiene variables
# El conjunto de variables Lasso alpha: 0.5 Iteracion: 14 no tiene variables
# El conjunto de variables Lasso alpha: 0.5 Iteracion: 14 no tiene variables
# El conjunto de variables Lasso alpha: 0.5 Iteracion: 14 no tiene variables
# El conjunto de variables Lasso alpha: 0.5 Iteracion: 14 no tiene variables
# El conjunto de variables Lasso alpha: 0.5 Iteracion: 14 no tiene variables
# El conjunto de variables Lasso alpha: 0.5 Iteracion: 14 no tiene variables
# El conjunto de variables Lasso alpha: 0.5 Iteracion: 14 no tiene variables
# El conjunto de variables Lasso alpha: 0.5 Iteracion: 14 no tiene variables
# El conjunto de variables Lasso alpha: 0.5 Iteracion: 14 no tiene variables
# El conjunto de variables Lasso alpha: 0.5 Iteracion: 14 no tiene variables
# El conjunto de variables Lasso alpha: 0.5 Iteracion: 14 no tiene variables
# El conjunto de variables Lasso alpha: 0.5 Iteracion: 14 no tiene variables
# El conjunto de variables Lasso alpha: 0.5 Iteracion: 14 no tiene variables
# El conjunto de variables Lasso alpha: 0.5 Iteracion: 14 no tiene variables
# El conjunto de variables Lasso alpha: 0.5 Iteracion: 14 no tiene variables
# El conjunto de variables Lasso alpha: 0.5 Iteracion: 14 no tiene variables
# El conjunto de variables Lasso alpha: 0.5 Iteracion: 14 no tiene variables
# El conjunto de variables Lasso alpha: 0.5 Iteracion: 14 no tiene variables
# El conjunto de variables Lasso alpha: 0.5 Iteracion: 14 no tiene variables
# El conjunto de variables Lasso alpha: 0.5 Iteracion: 14 no tiene variables
# El conjunto de variables Lasso alpha: 0.5 Iteracion: 14 no tiene variables
# El conjunto de variables Lasso alpha: 0.5 Iteracion: 14 no tiene variables
# El conjunto de variables Lasso alpha: 0.5 Iteracion: 14 no tiene variables
# El conjunto de variables Lasso alpha: 0.5 Iteracion: 14 no tiene variables
# El conjunto de variables Lasso alpha: 0.5 Iteracion: 14 no tiene variables
# El conjunto de variables Lasso alpha: 0.5 Iteracion: 14 no tiene variables
# El conjunto de variables Lasso alpha: 0.5 Iteracion: 14 no tiene variables
# El conjunto de variables Lasso alpha: 0.5 Iteracion: 14 no tiene variables
# El conjunto de variables Lasso alpha: 0.5 Iteracion: 14 no tiene variables
# El conjunto de variables Lasso alpha: 0.5 Iteracion: 14 no tiene variables
# El conjunto de variables Lasso alpha: 0.5 Iteracion: 14 no tiene variables
# El conjunto de variables Lasso alpha: 0.5 Iteracion: 14 no tiene variables
# El conjunto de variables Lasso alpha: 0.5 Iteracion: 14 no tiene variables
# El conjunto de variables Lasso alpha: 0.5 Iteracion: 14 no tiene variables
# El conjunto de variables Lasso alpha: 0.5 Iteracion: 14 no tiene variables
# El conjunto de variables Lasso alpha: 0.5 Iteracion: 14 no tiene variables
# El conjunto de variables Lasso alpha: 0.5 Iteracion: 14 no tiene variables
# El conjunto de variables Lasso alpha: 0.5 Iteracion: 14 no tiene variables
# El conjunto de variables Lasso alpha: 0.5 Iteracion: 14 no tiene variables
# El conjunto de variables Lasso alpha: 0.5 Iteracion: 14 no tiene variables
# El conjunto de variables Lasso alpha: 0.5 Iteracion: 14 no tiene variables
# El conjunto de variables Lasso alpha: 0.5 Iteracion: 14 no tiene variables
# El conjunto de variables Lasso alpha: 0.5 Iteracion: 14 no tiene variables
# El conjunto de variables Lasso alpha: 0.5 Iteracion: 14 no tiene variables
# El conjunto de variables Lasso alpha: 0.5 Iteracion: 14 no tiene variables
# El conjunto de variables Lasso alpha: 0.5 Iteracion: 14 no tiene variables
# El conjunto de variables Lasso alpha: 0.5 Iteracion: 14 no tiene variables
# El conjunto de variables Lasso alpha: 0.5 Iteracion: 14 no tiene variables
# El conjunto de variables Lasso alpha: 0.5 Iteracion: 14 no tiene variables
# El conjunto de variables Lasso alpha: 0.5 Iteracion: 14 no tiene variables
# El conjunto de variables Lasso alpha: 0.5 Iteracion: 14 no tiene variables
# El conjunto de variables Lasso alpha: 0.5 Iteracion: 14 no tiene variables
# El conjunto de variables Lasso alpha: 0.5 Iteracion: 14 no tiene variables
# El conjunto de variables Lasso alpha: 0.5 Iteracion: 14 no tiene variables
# El conjunto de variables Lasso alpha: 0.5 Iteracion: 14 no tiene variables
# El conjunto de variables Lasso alpha: 0.5 Iteracion: 14 no tiene variables
# El conjunto de variables Lasso alpha: 0.5 Iteracion: 14 no tiene variables
# El conjunto de variables Lasso alpha: 0.5 Iteracion: 14 no tiene variables
# El conjunto de variables Lasso alpha: 0.5 Iteracion: 14 no tiene variables
# El conjunto de variables Lasso alpha: 0.5 Iteracion: 14 no tiene variables
# El conjunto de variables Lasso alpha: 0.5 Iteracion: 14 no tiene variables
# El conjunto de variables Lasso alpha: 0.5 Iteracion: 14 no tiene variables
# El conjunto de variables Lasso alpha: 0.5 Iteracion: 14 no tiene variables
# El conjunto de variables Lasso alpha: 0.5 Iteracion: 14 no tiene variables
# El conjunto de variables Lasso alpha: 0.5 Iteracion: 14 no tiene variables
# Lasso alpha: 0.5 Iteracion: 15
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\numpy\core\fromnumeric.py:3257: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# e:\onedrive - celsia s.a e.s.p\maestría\metodos estadisticos avanzados\competencia\venv\lib\site-packages\numpy\core\_methods.py:161: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# Lasso alpha: 0.5 Iteracion: 54
# Lasso alpha: 0.5 Iteracion: 81
# Lasso alpha: 0.5 Iteracion: 91
# Modelo Diana 2

# %%
resultados.sort_values('Median: Mean squared error',ascending = True)
# Out:
#                                             Modelo  \
# 0           Cantidad de variables: 7 Iteracion: 76
# 0           Cantidad de variables: 6 Iteracion: 67
# 0           Cantidad de variables: 7 Iteracion: 21
# 0   Lasso alpha: 0.30000000000000004 Iteracion: 57
# 0            Cantidad de variables: 7 Iteracion: 8
# ..                                             ...
# 0                   Lasso alpha: 0.1 Iteracion: 16
# 0                   Lasso alpha: 0.1 Iteracion: 44
# 0                   Lasso alpha: 0.1 Iteracion: 86
# 0                   Lasso alpha: 0.1 Iteracion: 45
# 0                   Lasso alpha: 0.5 Iteracion: 14
#
#     Median: Mean squared error  Median: R2  Median: Accuray
# 0                     3.677757    0.140432         0.708333
# 0                     3.691690    0.132058         0.708333
# 0                     3.695670    0.130213         0.708333
# 0                     3.712891    0.117845         0.750000
# 0                     3.723520    0.137915         0.708333
# ..                         ...         ...              ...
# 0                     4.807330   -0.135322         0.666667
# 0                     4.879815   -0.119128         0.708333
# 0                     4.891113   -0.124913         0.666667
# 0                     4.945866   -0.140021         0.666667
# 0                          NaN         NaN              NaN
#
# [1285 rows x 4 columns]
